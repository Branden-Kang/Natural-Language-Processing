# %% [markdown]
# [Reference](https://medium.com/@francescofranco_39234/classifying-imdb-sentiment-with-keras-dropout-and-conv1d-fecaf69f52b5)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense, Dropout, Conv1D, MaxPooling1D
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
import matplotlib.pyplot as plt

# Model configuration
max_sequence_length = 100
num_distinct_words = 10000
embedding_output_dims = 15
loss_function = 'binary_crossentropy'
optimizer = 'adam'
additional_metrics = ['accuracy']
number_of_epochs = 100
verbosity_mode = True
validation_split = 0.20

# Load dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=num_distinct_words)
print(x_train.shape)
print(x_test.shape)

# Here, you'd normally test first that the model generalizes and concatenate all data
# (that is, normally, you'd perform e.g. K-fold Cross Validation first)
# Then, you can use all data for a full training run. Now, we'll use x_train for training only.

# Pad all sequences
padded_inputs = pad_sequences(x_train, maxlen=max_sequence_length, value = 0.0) # 0.0 because it corresponds with <PAD>
padded_inputs_test = pad_sequences(x_test, maxlen=max_sequence_length, value = 0.0) # 0.0 because it corresponds with <PAD>

# Obtain 3 texts
for i in np.random.randint(0, len(padded_inputs), 3):
  INDEX_FROM=3   # word index offset
  word_to_id = imdb.get_word_index()
  word_to_id = {k:(v+INDEX_FROM) for k,v in word_to_id.items()}
  word_to_id["<PAD>"] = 0
  word_to_id["<START>"] = 1
  word_to_id["<UNK>"] = 2
  word_to_id["<UNUSED>"] = 3

  id_to_word = {value:key for key,value in word_to_id.items()}
  print('=================================================')
  print(f'Sample = {i} | Length = {len(padded_inputs[i])}')
  print('=================================================')
  print(' '.join(id_to_word[id] for id in padded_inputs[i] ))

# Define the Keras model
model = Sequential()
model.add(Embedding(num_distinct_words, embedding_output_dims, input_length=max_sequence_length))
model.add(Dropout(0.50))
model.add(Conv1D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(Dropout(0.50))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dropout(0.50))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer=optimizer, loss=loss_function, metrics=additional_metrics)

# Give a summary
model.summary()

# Train the model
history = model.fit(padded_inputs, y_train, epochs=number_of_epochs, verbose=verbosity_mode, validation_split=validation_split)

# Test the model after training
test_results = model.evaluate(padded_inputs_test, y_test, verbose=False)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {100*test_results[1]}%')

# Visualize history
# Plot history: Validation loss
plt.plot(history.history['val_loss'])
plt.title('Validation loss history')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()

# Plot history: Accuracy
plt.plot(history.history['val_accuracy'])
plt.title('Validation accuracy history')
plt.ylabel('Accuracy value (%)')
plt.xlabel('No. epoch')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (25000,)
# (25000,)
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# =================================================
# Sample = 15658 | Length = 100
# =================================================
# characters themselves eddie <UNK> character is also one of the most stereotypical black guy <UNK> that just <UNK> people the wrong way he may or may not be a good actor but this movie doesn't allow for that kind of character exploration you want a movie that leaves the audience on the side of the bad guys <UNK> 11 this movie just makes you hate the bad guys instead of capturing the audience br br even the cars can't make up for this <UNK> of a movie that <UNK> that <UNK> <UNK> sums up this movie perfectly it just sucks
# =================================================
# Sample = 23163 | Length = 100
# =================================================
# it was directed by clint eastwood whose work i admire immensely the leads had absolutely no chemistry not for a second could i believe that there was anything deeper than lust between them the story just didn't ring true add to that stilted conversation tons of stereotypes and an incredibly slow plot that basically leads nowhere and you've got yourself a real stinker kay <UNK> nude scenes might be worthwhile for those seeking some <UNK> fare but otherwise this is a <UNK> waste of time my thoughts as i watched the movie was that <UNK> have been better titled cheesy
# =================================================
# Sample = 16965 | Length = 100
# =================================================
# much closer to reality than is teachers the <UNK> to survive <UNK> the insightful students who can see right through their pathetic <UNK> <UNK> the <UNK> of the whole situation all remind me of the schools i knew and their students when i saw the episode in which a student repeatedly tried to burn down the school i immediately <UNK> at high a classic line inspector i'm here to sack one of your teachers student welcome to <UNK> high i expect that many adults of my age think that <UNK> high is far fetched what a pity that it isn't
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.5278 - loss: 0.6901 - val_accuracy: 0.7690 - val_loss: 0.5276
# Epoch 2/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.8028 - loss: 0.4352 - val_accuracy: 0.8484 - val_loss: 0.3542
# Epoch 3/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.8656 - loss: 0.3085 - val_accuracy: 0.8504 - val_loss: 0.3295
# Epoch 4/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.8962 - loss: 0.2524 - val_accuracy: 0.8530 - val_loss: 0.3327
# Epoch 5/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9068 - loss: 0.2350 - val_accuracy: 0.8498 - val_loss: 0.3435
# Epoch 6/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9133 - loss: 0.2138 - val_accuracy: 0.8442 - val_loss: 0.3593
# Epoch 7/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9212 - loss: 0.1995 - val_accuracy: 0.8502 - val_loss: 0.3579
# Epoch 8/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9232 - loss: 0.1853 - val_accuracy: 0.8454 - val_loss: 0.3704
# Epoch 9/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.9306 - loss: 0.1774 - val_accuracy: 0.8404 - val_loss: 0.3838
# Epoch 10/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9339 - loss: 0.1658 - val_accuracy: 0.8424 - val_loss: 0.4029
# Epoch 11/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.9345 - loss: 0.1682 - val_accuracy: 0.8440 - val_loss: 0.4070
# Epoch 12/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9350 - loss: 0.1620 - val_accuracy: 0.8392 - val_loss: 0.4233
# Epoch 13/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9369 - loss: 0.1600 - val_accuracy: 0.8398 - val_loss: 0.4260
# Epoch 14/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9377 - loss: 0.1508 - val_accuracy: 0.8374 - val_loss: 0.4431
# Epoch 15/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9409 - loss: 0.1478 - val_accuracy: 0.8388 - val_loss: 0.4525
# Epoch 16/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9429 - loss: 0.1455 - val_accuracy: 0.8328 - val_loss: 0.4560
# Epoch 17/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9445 - loss: 0.1449 - val_accuracy: 0.8332 - val_loss: 0.4760
# Epoch 18/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9428 - loss: 0.1405 - val_accuracy: 0.8336 - val_loss: 0.4823
# Epoch 19/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9448 - loss: 0.1416 - val_accuracy: 0.8336 - val_loss: 0.4850
# Epoch 20/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9472 - loss: 0.1337 - val_accuracy: 0.8334 - val_loss: 0.4999
# Epoch 21/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9440 - loss: 0.1361 - val_accuracy: 0.8256 - val_loss: 0.5294
# Epoch 22/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9492 - loss: 0.1270 - val_accuracy: 0.8294 - val_loss: 0.5149
# Epoch 23/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9527 - loss: 0.1241 - val_accuracy: 0.8270 - val_loss: 0.5231
# Epoch 24/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9506 - loss: 0.1235 - val_accuracy: 0.8288 - val_loss: 0.5211
# Epoch 25/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9516 - loss: 0.1192 - val_accuracy: 0.8288 - val_loss: 0.5432
# Epoch 26/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9535 - loss: 0.1140 - val_accuracy: 0.8256 - val_loss: 0.5347
# Epoch 27/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9547 - loss: 0.1141 - val_accuracy: 0.8268 - val_loss: 0.5343
# Epoch 28/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9498 - loss: 0.1216 - val_accuracy: 0.8260 - val_loss: 0.5352
# Epoch 29/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9517 - loss: 0.1201 - val_accuracy: 0.8278 - val_loss: 0.5395
# Epoch 30/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9521 - loss: 0.1209 - val_accuracy: 0.8290 - val_loss: 0.5525
# Epoch 31/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9550 - loss: 0.1204 - val_accuracy: 0.8288 - val_loss: 0.5572
# Epoch 32/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.9566 - loss: 0.1088 - val_accuracy: 0.8282 - val_loss: 0.5584
# Epoch 33/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9553 - loss: 0.1127 - val_accuracy: 0.8236 - val_loss: 0.5721
# Epoch 34/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.9532 - loss: 0.1165 - val_accuracy: 0.8266 - val_loss: 0.5715
# Epoch 35/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9559 - loss: 0.1094 - val_accuracy: 0.8252 - val_loss: 0.5877
# Epoch 36/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9548 - loss: 0.1125 - val_accuracy: 0.8220 - val_loss: 0.5954
# Epoch 37/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9561 - loss: 0.1096 - val_accuracy: 0.8292 - val_loss: 0.5939
# Epoch 38/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.9574 - loss: 0.1036 - val_accuracy: 0.8252 - val_loss: 0.5937
# Epoch 39/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9549 - loss: 0.1138 - val_accuracy: 0.8232 - val_loss: 0.5996
# Epoch 40/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9564 - loss: 0.1098 - val_accuracy: 0.8248 - val_loss: 0.6028
# Epoch 41/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9570 - loss: 0.1103 - val_accuracy: 0.8280 - val_loss: 0.6059
# Epoch 42/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9561 - loss: 0.1092 - val_accuracy: 0.8238 - val_loss: 0.6056
# Epoch 43/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9587 - loss: 0.1043 - val_accuracy: 0.8230 - val_loss: 0.6306
# Epoch 44/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9594 - loss: 0.1039 - val_accuracy: 0.8240 - val_loss: 0.6181
# Epoch 45/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.9622 - loss: 0.0961 - val_accuracy: 0.8220 - val_loss: 0.6281
# Epoch 46/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9581 - loss: 0.1042 - val_accuracy: 0.8226 - val_loss: 0.6273
# Epoch 47/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.9594 - loss: 0.1000 - val_accuracy: 0.8240 - val_loss: 0.6261
# Epoch 48/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9580 - loss: 0.1069 - val_accuracy: 0.8222 - val_loss: 0.6301
# Epoch 49/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9619 - loss: 0.1013 - val_accuracy: 0.8244 - val_loss: 0.6256
# Epoch 50/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9616 - loss: 0.0953 - val_accuracy: 0.8234 - val_loss: 0.6337
# Epoch 51/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9604 - loss: 0.0994 - val_accuracy: 0.8256 - val_loss: 0.6353
# Epoch 52/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9624 - loss: 0.0994 - val_accuracy: 0.8262 - val_loss: 0.6378
# Epoch 53/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9611 - loss: 0.0986 - val_accuracy: 0.8262 - val_loss: 0.6523
# Epoch 54/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9589 - loss: 0.1026 - val_accuracy: 0.8228 - val_loss: 0.6386
# Epoch 55/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9578 - loss: 0.1085 - val_accuracy: 0.8252 - val_loss: 0.6419
# Epoch 56/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9578 - loss: 0.1026 - val_accuracy: 0.8250 - val_loss: 0.6306
# Epoch 57/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9610 - loss: 0.0998 - val_accuracy: 0.8238 - val_loss: 0.6446
# Epoch 58/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9618 - loss: 0.0976 - val_accuracy: 0.8224 - val_loss: 0.6506
# Epoch 59/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9625 - loss: 0.0939 - val_accuracy: 0.8194 - val_loss: 0.6818
# Epoch 60/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9617 - loss: 0.0975 - val_accuracy: 0.8200 - val_loss: 0.6695
# Epoch 61/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9605 - loss: 0.1023 - val_accuracy: 0.8220 - val_loss: 0.6614
# Epoch 62/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9639 - loss: 0.0983 - val_accuracy: 0.8228 - val_loss: 0.6447
# Epoch 63/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9612 - loss: 0.0991 - val_accuracy: 0.8228 - val_loss: 0.6581
# Epoch 64/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9656 - loss: 0.0943 - val_accuracy: 0.8210 - val_loss: 0.6624
# Epoch 65/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9620 - loss: 0.0961 - val_accuracy: 0.8234 - val_loss: 0.6643
# Epoch 66/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9645 - loss: 0.0899 - val_accuracy: 0.8196 - val_loss: 0.6700
# Epoch 67/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9641 - loss: 0.0952 - val_accuracy: 0.8220 - val_loss: 0.6567
# Epoch 68/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9612 - loss: 0.0992 - val_accuracy: 0.8206 - val_loss: 0.6629
# Epoch 69/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9637 - loss: 0.0965 - val_accuracy: 0.8222 - val_loss: 0.6691
# Epoch 70/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9618 - loss: 0.0940 - val_accuracy: 0.8212 - val_loss: 0.6649
# Epoch 71/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9609 - loss: 0.0971 - val_accuracy: 0.8226 - val_loss: 0.6786
# Epoch 72/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9645 - loss: 0.0905 - val_accuracy: 0.8220 - val_loss: 0.6770
# Epoch 73/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9624 - loss: 0.0921 - val_accuracy: 0.8210 - val_loss: 0.6935
# Epoch 74/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9624 - loss: 0.0956 - val_accuracy: 0.8216 - val_loss: 0.6842
# Epoch 75/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.9637 - loss: 0.0894 - val_accuracy: 0.8248 - val_loss: 0.6863
# Epoch 76/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9649 - loss: 0.0916 - val_accuracy: 0.8214 - val_loss: 0.6748
# Epoch 77/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.9663 - loss: 0.0891 - val_accuracy: 0.8206 - val_loss: 0.6883
# Epoch 78/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9643 - loss: 0.0912 - val_accuracy: 0.8228 - val_loss: 0.6831
# Epoch 79/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9649 - loss: 0.0939 - val_accuracy: 0.8244 - val_loss: 0.6894
# Epoch 80/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9636 - loss: 0.0926 - val_accuracy: 0.8214 - val_loss: 0.7055
# Epoch 81/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9647 - loss: 0.0959 - val_accuracy: 0.8218 - val_loss: 0.6980
# Epoch 82/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9675 - loss: 0.0876 - val_accuracy: 0.8202 - val_loss: 0.7048
# Epoch 83/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9660 - loss: 0.0895 - val_accuracy: 0.8236 - val_loss: 0.6927
# Epoch 84/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9638 - loss: 0.0945 - val_accuracy: 0.8192 - val_loss: 0.7075
# Epoch 85/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9649 - loss: 0.0880 - val_accuracy: 0.8202 - val_loss: 0.7065
# Epoch 86/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9662 - loss: 0.0868 - val_accuracy: 0.8226 - val_loss: 0.6993
# Epoch 87/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9652 - loss: 0.0895 - val_accuracy: 0.8192 - val_loss: 0.7159
# Epoch 88/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9645 - loss: 0.0922 - val_accuracy: 0.8194 - val_loss: 0.7079
# Epoch 89/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9661 - loss: 0.0876 - val_accuracy: 0.8212 - val_loss: 0.7245
# Epoch 90/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9631 - loss: 0.0907 - val_accuracy: 0.8194 - val_loss: 0.7109
# Epoch 91/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9682 - loss: 0.0886 - val_accuracy: 0.8234 - val_loss: 0.7243
# Epoch 92/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9645 - loss: 0.0898 - val_accuracy: 0.8198 - val_loss: 0.7287
# Epoch 93/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9644 - loss: 0.0949 - val_accuracy: 0.8206 - val_loss: 0.7037
# Epoch 94/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9642 - loss: 0.0875 - val_accuracy: 0.8204 - val_loss: 0.7089
# Epoch 95/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9688 - loss: 0.0841 - val_accuracy: 0.8210 - val_loss: 0.7048
# Epoch 96/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9653 - loss: 0.0872 - val_accuracy: 0.8202 - val_loss: 0.7033
# Epoch 97/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9647 - loss: 0.0936 - val_accuracy: 0.8216 - val_loss: 0.7116
# Epoch 98/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9658 - loss: 0.0897 - val_accuracy: 0.8210 - val_loss: 0.7002
# Epoch 99/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9653 - loss: 0.0904 - val_accuracy: 0.8196 - val_loss: 0.7044
# Epoch 100/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9672 - loss: 0.0863 - val_accuracy: 0.8208 - val_loss: 0.7255
# Test results - Loss: 0.73951256275177 - Accuracy: 80.867999792099%

# %%
# Texts
text_bad = x_train[7737]
text_good = x_train[449]
texts = (text_bad, text_good)
padded_texts = pad_sequences(texts, maxlen=max_sequence_length, value = 0.0) # 0.0 because it corresponds with <PAD>

# Generate predictions
predictions = model.predict(padded_texts)
print(predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# [[0.00166189]
#  [0.9986606 ]]
