# %% [markdown]
# [Reference](https://medium.com/mlworks/getting-started-with-nemoclaw-5943baff1ed3)

# %% [markdown]
# ```
# curl -fsSL https://nvidia.com/nemoclaw.sh | bash
# ```

# %% [markdown]
# ```
# nemoclaw testing connect
# ```

# %% [markdown]
# ```
# openclaw agent --agent main --local -m "hello" --session-id test
# ```

# %% [markdown]
# ```
# openclaw tui
# ```
