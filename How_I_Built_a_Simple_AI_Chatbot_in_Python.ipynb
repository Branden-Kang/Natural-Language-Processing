# %% [markdown]
# [Reference](https://medium.com/@tricky16122000/how-i-built-a-simple-ai-chatbot-in-python-with-just-100-lines-of-code-31b85a93719c)

# %%
import nltk
import random
import string

from nltk.chat.util import Chat, reflections

# Download required NLTK data (first time only)
nltk.download('punkt')

# Define simple patterns and responses
pairs = [
    [r"hi|hello|hey", ["Hey there!", "Hello!", "Hi, how can I help you?"]],
    [r"what is your name\??", ["I'm a chatbot, but you can call me Bob."]],
    [r"how are you\??", ["I'm just code, but thanks for asking!", "Doing great in binary."]],
    [r"(.*) your favorite (.*)?", ["I don't have preferences, but I like your curiosity."]],
    [r"bye|exit|quit", ["Goodbye! Have a great day.", "See ya! Come back soon."]],
    [r"(.*)", ["Tell me more.", "Why do you say that?", "Interesting... go on."]]
]

chatbot = Chat(pairs, reflections)
print("Hi! I'm a simple chatbot. Type 'quit' to exit.")
chatbot.converse()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Hi! I'm a simple chatbot. Type 'quit' to exit.
# >Hi
# Hi, how can I help you?
# >How are you?
# Doing great in binary.
# >What is your name?
# I'm a chatbot, but you can call me Bob.
# >Hi Bob
# Hi, how can I help you?
# >What do you do for a living?
# Tell me more.
# >quit
# Goodbye! Have a great day.
