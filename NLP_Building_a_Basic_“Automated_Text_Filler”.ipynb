# %% [markdown]
# [Reference](https://medium.com/geekculture/nlp-building-a-basic-automated-text-filler-an-introduction-d560ac2b5cdf)

# %%
from bs4 import BeautifulSoup
from nltk.util import ngrams
from collections import defaultdict
from nltk import trigrams
from nltk.tokenize import RegexpTokenizer
import requests

#load fetch speech text from blog
response = requests.get("https://maxsiollun.wordpress.com/great-speeches-in-nigerias-history/")
soup = BeautifulSoup(response.text,'html.parser')
sentence = soup.find_all('p',text=True)
print(sentence[1:3])
# Out:
# [<p>Violence has never been an instrument used by us, as founding fathers of the Nigerian Republic, to solve political problems. In the British tradition, we talked the Colonial Office into accepting our challenges for the demerits and merits of our case for self-government.  After six constitutional conferences in 1953, 1954, 1957, 1958, 1959, and 1960, Great Britain conceded to us the right to assert our political independence as from October 1, 1960.  None of the Nigerian political parties ever adopted violent means to gain our political freedom and we are happy to claim that not a drop of British or Nigerian blood was shed in the course of our national struggle for our place in the sun. This historical fact enabled me to state publicly in Nigeria that Her Majesty’s Government has presented self-government to us on a platter of gold. Of course, my contemporaries scorned at me, but the facts of history are irrefutable. I consider it most unfortunate that our ‘Young Turks’ decided to introduce the element of violent revolution into Nigerian politics. No matter how they and our general public might have been provoked by obstinate and perhaps grasping politicians, it is an unwise policy. I have contacted General Aguiyi-Ironsi, General Officer Commanding the Nigerian armed forces, who I understand, has now assumed the reins of the Federal Government. I offered my services for any peace overtures to stop further bloodshed, to placate the mutinous officers, and to restore law and order. As soon as I hear from him, I shall make arrangements to return home. As far as I am concerned, I regard the killings of our political and military leaders as a national calamity.</p>, <p class="MsoNormal" style="margin:0;"><strong> </strong></p>]

# %% [markdown]
# # Preprocess Text

# %%
note='' 
#we will merge the list string values into a single string
for line in sentence[1:3]:
    note+= str(line)
#convert text to lower case
sentence=note.lower()
#convert Sentence into Tokens and extract all punctuations
tokenizer = RegexpTokenizer(r'\w+')
tk_sentence=tokenizer.tokenize(sentence)

# %%
tk_sentence
# Out:
# ['p',
#  'violence',
#  'has',
#  'never',
#  'been',
#  'an',
#  'instrument',
#  'used',
#  'by',
#  'us',
#  'as',
#  'founding',
#  'fathers',
#  'of',
#  'the',
#  'nigerian',
#  'republic',
#  'to',
#  'solve',
#  'political',
#  'problems',
#  'in',
#  'the',
#  'british',
#  'tradition',
#  'we',
#  'talked',
#  'the',
#  'colonial',
#  'office',
#  'into',
#  'accepting',
#  'our',
#  'challenges',
#  'for',
#  'the',
#  'demerits',
#  'and',
#  'merits',
#  'of',
#  'our',
#  'case',
#  'for',
#  'self',
#  'government',
#  'after',
#  'six',
#  'constitutional',
#  'conferences',
#  'in',
#  '1953',
#  '1954',
#  '1957',
#  '1958',
#  '1959',
#  'and',
#  '1960',
#  'great',
#  'britain',
#  'conceded',
#  'to',
#  'us',
#  'the',
#  'right',
#  'to',
#  'assert',
#  'our',
#  'political',
#  'independence',
#  'as',
#  'from',
#  'october',
#  '1',
#  '1960',
#  'none',
#  'of',
#  'the',
#  'nigerian',
#  'political',
#  'parties',
#  'ever',
#  'adopted',
#  'violent',
#  'means',
#  'to',
#  'gain',
#  'our',
#  'political',
#  'freedom',
#  'and',
#  'we',
#  'are',
#  'happy',
#  'to',
#  'claim',
#  'that',
#  'not',
#  'a',
#  'drop',
#  'of',
#  'british',
#  'or',
#  'nigerian',
#  'blood',
#  'was',
#  'shed',
#  'in',
#  'the',
#  'course',
#  'of',
#  'our',
#  'national',
#  'struggle',
#  'for',
#  'our',
#  'place',
#  'in',
#  'the',
#  'sun',
#  'this',
#  'historical',
#  'fact',
#  'enabled',
#  'me',
#  'to',
#  'state',
#  'publicly',
#  'in',
#  'nigeria',
#  'that',
#  'her',
#  'majesty',
#  's',
#  'government',
#  'has',
#  'presented',
#  'self',
#  'government',
#  'to',
#  'us',
#  'on',
#  'a',
#  'platter',
#  'of',
#  'gold',
#  'of',
#  'course',
#  'my',
#  'contemporaries',
#  'scorned',
#  'at',
#  'me',
#  'but',
#  'the',
#  'facts',
#  'of',
#  'history',
#  'are',
#  'irrefutable',
#  'i',
#  'consider',
#  'it',
#  'most',
#  'unfortunate',
#  'that',
#  'our',
#  'young',
#  'turks',
#  'decided',
#  'to',
#  'introduce',
#  'the',
#  'element',
#  'of',
#  'violent',
#  'revolution',
#  'into',
#  'nigerian',
#  'politics',
#  'no',
#  'matter',
#  'how',
#  'they',
#  'and',
#  'our',
#  'general',
#  'public',
#  'might',
#  'have',
#  'been',
#  'provoked',
#  'by',
#  'obstinate',
#  'and',
#  'perhaps',
#  'grasping',
#  'politicians',
#  'it',
#  'is',
#  'an',
#  'unwise',
#  'policy',
#  'i',
#  'have',
#  'contacted',
#  'general',
#  'aguiyi',
#  'ironsi',
#  'general',
#  'officer',
#  'commanding',
#  'the',
#  'nigerian',
#  'armed',
#  'forces',
#  'who',
#  'i',
#  'understand',
#  'has',
#  'now',
#  'assumed',
#  'the',
#  'reins',
#  'of',
#  'the',
#  'federal',
#  'government',
#  'i',
#  'offered',
#  'my',
#  'services',
#  'for',
#  'any',
#  'peace',
#  'overtures',
#  'to',
#  'stop',
#  'further',
#  'bloodshed',
#  'to',
#  'placate',
#  'the',
#  'mutinous',
#  'officers',
#  'and',
#  'to',
#  'restore',
#  'law',
#  'and',
#  'order',
#  'as',
#  'soon',
#  'as',
#  'i',
#  'hear',
#  'from',
#  'him',
#  'i',
#  'shall',
#  'make',
#  'arrangements',
#  'to',
#  'return',
#  'home',
#  'as',
#  'far',
#  'as',
#  'i',
#  'am',
#  'concerned',
#  'i',
#  'regard',
#  'the',
#  'killings',
#  'of',
#  'our',
#  'political',
#  'and',
#  'military',
#  'leaders',
#  'as',
#  'a',
#  'national',
#  'calamity',
#  'p',
#  'p',
#  'class',
#  'msonormal',
#  'style',
#  'margin',
#  '0',
#  'strong',
#  'strong',
#  'p']

# %% [markdown]
# # Create Tri-grams

# %%
gram_sentence=list(ngrams(tk_sentence, 3))
gram_sentence
# Out:
# [('p', 'violence', 'has'),
#  ('violence', 'has', 'never'),
#  ('has', 'never', 'been'),
#  ('never', 'been', 'an'),
#  ('been', 'an', 'instrument'),
#  ('an', 'instrument', 'used'),
#  ('instrument', 'used', 'by'),
#  ('used', 'by', 'us'),
#  ('by', 'us', 'as'),
#  ('us', 'as', 'founding'),
#  ('as', 'founding', 'fathers'),
#  ('founding', 'fathers', 'of'),
#  ('fathers', 'of', 'the'),
#  ('of', 'the', 'nigerian'),
#  ('the', 'nigerian', 'republic'),
#  ('nigerian', 'republic', 'to'),
#  ('republic', 'to', 'solve'),
#  ('to', 'solve', 'political'),
#  ('solve', 'political', 'problems'),
#  ('political', 'problems', 'in'),
#  ('problems', 'in', 'the'),
#  ('in', 'the', 'british'),
#  ('the', 'british', 'tradition'),
#  ('british', 'tradition', 'we'),
#  ('tradition', 'we', 'talked'),
#  ('we', 'talked', 'the'),
#  ('talked', 'the', 'colonial'),
#  ('the', 'colonial', 'office'),
#  ('colonial', 'office', 'into'),
#  ('office', 'into', 'accepting'),
#  ('into', 'accepting', 'our'),
#  ('accepting', 'our', 'challenges'),
#  ('our', 'challenges', 'for'),
#  ('challenges', 'for', 'the'),
#  ('for', 'the', 'demerits'),
#  ('the', 'demerits', 'and'),
#  ('demerits', 'and', 'merits'),
#  ('and', 'merits', 'of'),
#  ('merits', 'of', 'our'),
#  ('of', 'our', 'case'),
#  ('our', 'case', 'for'),
#  ('case', 'for', 'self'),
#  ('for', 'self', 'government'),
#  ('self', 'government', 'after'),
#  ('government', 'after', 'six'),
#  ('after', 'six', 'constitutional'),
#  ('six', 'constitutional', 'conferences'),
#  ('constitutional', 'conferences', 'in'),
#  ('conferences', 'in', '1953'),
#  ('in', '1953', '1954'),
#  ('1953', '1954', '1957'),
#  ('1954', '1957', '1958'),
#  ('1957', '1958', '1959'),
#  ('1958', '1959', 'and'),
#  ('1959', 'and', '1960'),
#  ('and', '1960', 'great'),
#  ('1960', 'great', 'britain'),
#  ('great', 'britain', 'conceded'),
#  ('britain', 'conceded', 'to'),
#  ('conceded', 'to', 'us'),
#  ('to', 'us', 'the'),
#  ('us', 'the', 'right'),
#  ('the', 'right', 'to'),
#  ('right', 'to', 'assert'),
#  ('to', 'assert', 'our'),
#  ('assert', 'our', 'political'),
#  ('our', 'political', 'independence'),
#  ('political', 'independence', 'as'),
#  ('independence', 'as', 'from'),
#  ('as', 'from', 'october'),
#  ('from', 'october', '1'),
#  ('october', '1', '1960'),
#  ('1', '1960', 'none'),
#  ('1960', 'none', 'of'),
#  ('none', 'of', 'the'),
#  ('of', 'the', 'nigerian'),
#  ('the', 'nigerian', 'political'),
#  ('nigerian', 'political', 'parties'),
#  ('political', 'parties', 'ever'),
#  ('parties', 'ever', 'adopted'),
#  ('ever', 'adopted', 'violent'),
#  ('adopted', 'violent', 'means'),
#  ('violent', 'means', 'to'),
#  ('means', 'to', 'gain'),
#  ('to', 'gain', 'our'),
#  ('gain', 'our', 'political'),
#  ('our', 'political', 'freedom'),
#  ('political', 'freedom', 'and'),
#  ('freedom', 'and', 'we'),
#  ('and', 'we', 'are'),
#  ('we', 'are', 'happy'),
#  ('are', 'happy', 'to'),
#  ('happy', 'to', 'claim'),
#  ('to', 'claim', 'that'),
#  ('claim', 'that', 'not'),
#  ('that', 'not', 'a'),
#  ('not', 'a', 'drop'),
#  ('a', 'drop', 'of'),
#  ('drop', 'of', 'british'),
#  ('of', 'british', 'or'),
#  ('british', 'or', 'nigerian'),
#  ('or', 'nigerian', 'blood'),
#  ('nigerian', 'blood', 'was'),
#  ('blood', 'was', 'shed'),
#  ('was', 'shed', 'in'),
#  ('shed', 'in', 'the'),
#  ('in', 'the', 'course'),
#  ('the', 'course', 'of'),
#  ('course', 'of', 'our'),
#  ('of', 'our', 'national'),
#  ('our', 'national', 'struggle'),
#  ('national', 'struggle', 'for'),
#  ('struggle', 'for', 'our'),
#  ('for', 'our', 'place'),
#  ('our', 'place', 'in'),
#  ('place', 'in', 'the'),
#  ('in', 'the', 'sun'),
#  ('the', 'sun', 'this'),
#  ('sun', 'this', 'historical'),
#  ('this', 'historical', 'fact'),
#  ('historical', 'fact', 'enabled'),
#  ('fact', 'enabled', 'me'),
#  ('enabled', 'me', 'to'),
#  ('me', 'to', 'state'),
#  ('to', 'state', 'publicly'),
#  ('state', 'publicly', 'in'),
#  ('publicly', 'in', 'nigeria'),
#  ('in', 'nigeria', 'that'),
#  ('nigeria', 'that', 'her'),
#  ('that', 'her', 'majesty'),
#  ('her', 'majesty', 's'),
#  ('majesty', 's', 'government'),
#  ('s', 'government', 'has'),
#  ('government', 'has', 'presented'),
#  ('has', 'presented', 'self'),
#  ('presented', 'self', 'government'),
#  ('self', 'government', 'to'),
#  ('government', 'to', 'us'),
#  ('to', 'us', 'on'),
#  ('us', 'on', 'a'),
#  ('on', 'a', 'platter'),
#  ('a', 'platter', 'of'),
#  ('platter', 'of', 'gold'),
#  ('of', 'gold', 'of'),
#  ('gold', 'of', 'course'),
#  ('of', 'course', 'my'),
#  ('course', 'my', 'contemporaries'),
#  ('my', 'contemporaries', 'scorned'),
#  ('contemporaries', 'scorned', 'at'),
#  ('scorned', 'at', 'me'),
#  ('at', 'me', 'but'),
#  ('me', 'but', 'the'),
#  ('but', 'the', 'facts'),
#  ('the', 'facts', 'of'),
#  ('facts', 'of', 'history'),
#  ('of', 'history', 'are'),
#  ('history', 'are', 'irrefutable'),
#  ('are', 'irrefutable', 'i'),
#  ('irrefutable', 'i', 'consider'),
#  ('i', 'consider', 'it'),
#  ('consider', 'it', 'most'),
#  ('it', 'most', 'unfortunate'),
#  ('most', 'unfortunate', 'that'),
#  ('unfortunate', 'that', 'our'),
#  ('that', 'our', 'young'),
#  ('our', 'young', 'turks'),
#  ('young', 'turks', 'decided'),
#  ('turks', 'decided', 'to'),
#  ('decided', 'to', 'introduce'),
#  ('to', 'introduce', 'the'),
#  ('introduce', 'the', 'element'),
#  ('the', 'element', 'of'),
#  ('element', 'of', 'violent'),
#  ('of', 'violent', 'revolution'),
#  ('violent', 'revolution', 'into'),
#  ('revolution', 'into', 'nigerian'),
#  ('into', 'nigerian', 'politics'),
#  ('nigerian', 'politics', 'no'),
#  ('politics', 'no', 'matter'),
#  ('no', 'matter', 'how'),
#  ('matter', 'how', 'they'),
#  ('how', 'they', 'and'),
#  ('they', 'and', 'our'),
#  ('and', 'our', 'general'),
#  ('our', 'general', 'public'),
#  ('general', 'public', 'might'),
#  ('public', 'might', 'have'),
#  ('might', 'have', 'been'),
#  ('have', 'been', 'provoked'),
#  ('been', 'provoked', 'by'),
#  ('provoked', 'by', 'obstinate'),
#  ('by', 'obstinate', 'and'),
#  ('obstinate', 'and', 'perhaps'),
#  ('and', 'perhaps', 'grasping'),
#  ('perhaps', 'grasping', 'politicians'),
#  ('grasping', 'politicians', 'it'),
#  ('politicians', 'it', 'is'),
#  ('it', 'is', 'an'),
#  ('is', 'an', 'unwise'),
#  ('an', 'unwise', 'policy'),
#  ('unwise', 'policy', 'i'),
#  ('policy', 'i', 'have'),
#  ('i', 'have', 'contacted'),
#  ('have', 'contacted', 'general'),
#  ('contacted', 'general', 'aguiyi'),
#  ('general', 'aguiyi', 'ironsi'),
#  ('aguiyi', 'ironsi', 'general'),
#  ('ironsi', 'general', 'officer'),
#  ('general', 'officer', 'commanding'),
#  ('officer', 'commanding', 'the'),
#  ('commanding', 'the', 'nigerian'),
#  ('the', 'nigerian', 'armed'),
#  ('nigerian', 'armed', 'forces'),
#  ('armed', 'forces', 'who'),
#  ('forces', 'who', 'i'),
#  ('who', 'i', 'understand'),
#  ('i', 'understand', 'has'),
#  ('understand', 'has', 'now'),
#  ('has', 'now', 'assumed'),
#  ('now', 'assumed', 'the'),
#  ('assumed', 'the', 'reins'),
#  ('the', 'reins', 'of'),
#  ('reins', 'of', 'the'),
#  ('of', 'the', 'federal'),
#  ('the', 'federal', 'government'),
#  ('federal', 'government', 'i'),
#  ('government', 'i', 'offered'),
#  ('i', 'offered', 'my'),
#  ('offered', 'my', 'services'),
#  ('my', 'services', 'for'),
#  ('services', 'for', 'any'),
#  ('for', 'any', 'peace'),
#  ('any', 'peace', 'overtures'),
#  ('peace', 'overtures', 'to'),
#  ('overtures', 'to', 'stop'),
#  ('to', 'stop', 'further'),
#  ('stop', 'further', 'bloodshed'),
#  ('further', 'bloodshed', 'to'),
#  ('bloodshed', 'to', 'placate'),
#  ('to', 'placate', 'the'),
#  ('placate', 'the', 'mutinous'),
#  ('the', 'mutinous', 'officers'),
#  ('mutinous', 'officers', 'and'),
#  ('officers', 'and', 'to'),
#  ('and', 'to', 'restore'),
#  ('to', 'restore', 'law'),
#  ('restore', 'law', 'and'),
#  ('law', 'and', 'order'),
#  ('and', 'order', 'as'),
#  ('order', 'as', 'soon'),
#  ('as', 'soon', 'as'),
#  ('soon', 'as', 'i'),
#  ('as', 'i', 'hear'),
#  ('i', 'hear', 'from'),
#  ('hear', 'from', 'him'),
#  ('from', 'him', 'i'),
#  ('him', 'i', 'shall'),
#  ('i', 'shall', 'make'),
#  ('shall', 'make', 'arrangements'),
#  ('make', 'arrangements', 'to'),
#  ('arrangements', 'to', 'return'),
#  ('to', 'return', 'home'),
#  ('return', 'home', 'as'),
#  ('home', 'as', 'far'),
#  ('as', 'far', 'as'),
#  ('far', 'as', 'i'),
#  ('as', 'i', 'am'),
#  ('i', 'am', 'concerned'),
#  ('am', 'concerned', 'i'),
#  ('concerned', 'i', 'regard'),
#  ('i', 'regard', 'the'),
#  ('regard', 'the', 'killings'),
#  ('the', 'killings', 'of'),
#  ('killings', 'of', 'our'),
#  ('of', 'our', 'political'),
#  ('our', 'political', 'and'),
#  ('political', 'and', 'military'),
#  ('and', 'military', 'leaders'),
#  ('military', 'leaders', 'as'),
#  ('leaders', 'as', 'a'),
#  ('as', 'a', 'national'),
#  ('a', 'national', 'calamity'),
#  ('national', 'calamity', 'p'),
#  ('calamity', 'p', 'p'),
#  ('p', 'p', 'class'),
#  ('p', 'class', 'msonormal'),
#  ('class', 'msonormal', 'style'),
#  ('msonormal', 'style', 'margin'),
#  ('style', 'margin', '0'),
#  ('margin', '0', 'strong'),
#  ('0', 'strong', 'strong'),
#  ('strong', 'strong', 'p')]

# %% [markdown]
# # Build Markov Model

# %%
# Create Word Model
word_model = defaultdict(lambda: defaultdict(lambda: 0))


for sentence in tk_sentence:
    for first_word, second_word, word_label in trigrams(tk_sentence,pad_left=True,pad_right=True):
        word_model[(first_word, second_word)][word_label] += 1
dict(word_model)
# Out:
# {('0', 'strong'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'strong': 294}),
#  ('1', '1960'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'none': 294}),
#  ('1953', '1954'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'1957': 294}),
#  ('1954', '1957'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'1958': 294}),
#  ('1957', '1958'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'1959': 294}),
#  ('1958', '1959'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'and': 294}),
#  ('1959', 'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'1960': 294}),
#  ('1960', 'great'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'britain': 294}),
#  ('1960', 'none'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 294}),
#  ('a', 'drop'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 294}),
#  ('a', 'national'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'calamity': 294}),
#  ('a', 'platter'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 294}),
#  ('accepting',
#   'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'challenges': 294}),
#  ('adopted',
#   'violent'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'means': 294}),
#  ('after', 'six'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'constitutional': 294}),
#  ('aguiyi',
#   'ironsi'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'general': 294}),
#  ('am',
#   'concerned'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'i': 294}),
#  ('an',
#   'instrument'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'used': 294}),
#  ('an', 'unwise'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'policy': 294}),
#  ('and', '1960'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'great': 294}),
#  ('and', 'merits'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 294}),
#  ('and',
#   'military'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'leaders': 294}),
#  ('and', 'order'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'as': 294}),
#  ('and', 'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'general': 294}),
#  ('and',
#   'perhaps'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'grasping': 294}),
#  ('and', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'restore': 294}),
#  ('and', 'we'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'are': 294}),
#  ('any', 'peace'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'overtures': 294}),
#  ('are', 'happy'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'to': 294}),
#  ('are',
#   'irrefutable'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'i': 294}),
#  ('armed',
#   'forces'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'who': 294}),
#  ('arrangements',
#   'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'return': 294}),
#  ('as', 'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'national': 294}),
#  ('as', 'far'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'as': 294}),
#  ('as',
#   'founding'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'fathers': 294}),
#  ('as', 'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'october': 294}),
#  ('as', 'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'am': 294, 'hear': 294}),
#  ('as', 'soon'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'as': 294}),
#  ('assert', 'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'political': 294}),
#  ('assumed',
#   'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'reins': 294}),
#  ('at', 'me'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'but': 294}),
#  ('been', 'an'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'instrument': 294}),
#  ('been',
#   'provoked'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'by': 294}),
#  ('blood', 'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'shed': 294}),
#  ('bloodshed',
#   'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'placate': 294}),
#  ('britain',
#   'conceded'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 294}),
#  ('british', 'or'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'nigerian': 294}),
#  ('british',
#   'tradition'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'we': 294}),
#  ('but', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'facts': 294}),
#  ('by',
#   'obstinate'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 294}),
#  ('by', 'us'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'as': 294}),
#  ('calamity', 'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'p': 294}),
#  ('case', 'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'self': 294}),
#  ('challenges',
#   'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 294}),
#  ('claim', 'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'not': 294}),
#  ('class',
#   'msonormal'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'style': 294}),
#  ('colonial',
#   'office'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'into': 294}),
#  ('commanding',
#   'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'nigerian': 294}),
#  ('conceded',
#   'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'us': 294}),
#  ('concerned',
#   'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'regard': 294}),
#  ('conferences',
#   'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'1953': 294}),
#  ('consider',
#   'it'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'most': 294}),
#  ('constitutional',
#   'conferences'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 294}),
#  ('contacted',
#   'general'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'aguiyi': 294}),
#  ('contemporaries',
#   'scorned'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'at': 294}),
#  ('course', 'my'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'contemporaries': 294}),
#  ('course', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'our': 294}),
#  ('decided', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'introduce': 294}),
#  ('demerits',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'merits': 294}),
#  ('drop', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'british': 294}),
#  ('element', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'violent': 294}),
#  ('enabled', 'me'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'to': 294}),
#  ('ever',
#   'adopted'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'violent': 294}),
#  ('fact',
#   'enabled'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'me': 294}),
#  ('facts', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'history': 294}),
#  ('far', 'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'i': 294}),
#  ('fathers', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 294}),
#  ('federal',
#   'government'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'i': 294}),
#  ('for', 'any'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'peace': 294}),
#  ('for', 'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'place': 294}),
#  ('for', 'self'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'government': 294}),
#  ('for', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'demerits': 294}),
#  ('forces', 'who'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'i': 294}),
#  ('founding',
#   'fathers'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 294}),
#  ('freedom',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'we': 294}),
#  ('from', 'him'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'i': 294}),
#  ('from',
#   'october'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'1': 294}),
#  ('further',
#   'bloodshed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 294}),
#  ('gain', 'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'political': 294}),
#  ('general',
#   'aguiyi'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'ironsi': 294}),
#  ('general',
#   'officer'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'commanding': 294}),
#  ('general',
#   'public'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'might': 294}),
#  ('gold', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'course': 294}),
#  ('government',
#   'after'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'six': 294}),
#  ('government',
#   'has'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'presented': 294}),
#  ('government',
#   'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'offered': 294}),
#  ('government',
#   'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'us': 294}),
#  ('grasping',
#   'politicians'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'it': 294}),
#  ('great',
#   'britain'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'conceded': 294}),
#  ('happy', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'claim': 294}),
#  ('has', 'never'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'been': 294}),
#  ('has', 'now'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'assumed': 294}),
#  ('has',
#   'presented'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'self': 294}),
#  ('have', 'been'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'provoked': 294}),
#  ('have',
#   'contacted'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'general': 294}),
#  ('hear', 'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'him': 294}),
#  ('her',
#   'majesty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'s': 294}),
#  ('him', 'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'shall': 294}),
#  ('historical',
#   'fact'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'enabled': 294}),
#  ('history',
#   'are'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'irrefutable': 294}),
#  ('home', 'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'far': 294}),
#  ('how', 'they'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'and': 294}),
#  ('i', 'am'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'concerned': 294}),
#  ('i', 'consider'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'it': 294}),
#  ('i', 'have'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'contacted': 294}),
#  ('i', 'hear'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'from': 294}),
#  ('i', 'offered'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'my': 294}),
#  ('i', 'regard'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 294}),
#  ('i', 'shall'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'make': 294}),
#  ('i',
#   'understand'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'has': 294}),
#  ('in', '1953'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'1954': 294}),
#  ('in', 'nigeria'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'that': 294}),
#  ('in', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'british': 294, 'course': 294, 'sun': 294}),
#  ('independence',
#   'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'from': 294}),
#  ('instrument',
#   'used'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'by': 294}),
#  ('into',
#   'accepting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'our': 294}),
#  ('into',
#   'nigerian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'politics': 294}),
#  ('introduce',
#   'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'element': 294}),
#  ('ironsi',
#   'general'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'officer': 294}),
#  ('irrefutable',
#   'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'consider': 294}),
#  ('is', 'an'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'unwise': 294}),
#  ('it', 'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'an': 294}),
#  ('it', 'most'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'unfortunate': 294}),
#  ('killings',
#   'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'our': 294}),
#  ('law', 'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'order': 294}),
#  ('leaders', 'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'a': 294}),
#  ('majesty', 's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'government': 294}),
#  ('make',
#   'arrangements'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 294}),
#  ('margin', '0'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'strong': 294}),
#  ('matter', 'how'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'they': 294}),
#  ('me', 'but'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 294}),
#  ('me', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'state': 294}),
#  ('means', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'gain': 294}),
#  ('merits', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'our': 294}),
#  ('might', 'have'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'been': 294}),
#  ('military',
#   'leaders'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'as': 294}),
#  ('most',
#   'unfortunate'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'that': 294}),
#  ('msonormal',
#   'style'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'margin': 294}),
#  ('mutinous',
#   'officers'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 294}),
#  ('my',
#   'contemporaries'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'scorned': 294}),
#  ('my',
#   'services'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'for': 294}),
#  ('national',
#   'calamity'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'p': 294}),
#  ('national',
#   'struggle'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'for': 294}),
#  ('never', 'been'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'an': 294}),
#  ('nigeria',
#   'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'her': 294}),
#  ('nigerian',
#   'armed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'forces': 294}),
#  ('nigerian',
#   'blood'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'was': 294}),
#  ('nigerian',
#   'political'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'parties': 294}),
#  ('nigerian',
#   'politics'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'no': 294}),
#  ('nigerian',
#   'republic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 294}),
#  ('no', 'matter'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'how': 294}),
#  ('none', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 294}),
#  ('not', 'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'drop': 294}),
#  ('now',
#   'assumed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 294}),
#  ('obstinate',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'perhaps': 294}),
#  ('october', '1'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'1960': 294}),
#  ('of', 'british'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'or': 294}),
#  ('of', 'course'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'my': 294}),
#  ('of', 'gold'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 294}),
#  ('of', 'history'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'are': 294}),
#  ('of', 'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'case': 294, 'national': 294, 'political': 294}),
#  ('of', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'federal': 294, 'nigerian': 588}),
#  ('of', 'violent'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'revolution': 294}),
#  ('offered', 'my'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'services': 294}),
#  ('office',
#   'into'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'accepting': 294}),
#  ('officer',
#   'commanding'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 294}),
#  ('officers',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 294}),
#  ('on', 'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'platter': 294}),
#  ('or',
#   'nigerian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'blood': 294}),
#  ('order', 'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'soon': 294}),
#  ('our', 'case'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'for': 294}),
#  ('our',
#   'challenges'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'for': 294}),
#  ('our',
#   'general'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'public': 294}),
#  ('our',
#   'national'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'struggle': 294}),
#  ('our', 'place'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'in': 294}),
#  ('our',
#   'political'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 294,
#               'freedom': 294,
#               'independence': 294}),
#  ('our', 'young'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'turks': 294}),
#  ('overtures',
#   'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'stop': 294}),
#  ('p', 'class'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'msonormal': 294}),
#  ('p', 'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'class': 294}),
#  ('p', 'violence'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'has': 294}),
#  ('p', None): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {None: 294}),
#  ('parties',
#   'ever'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'adopted': 294}),
#  ('peace',
#   'overtures'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 294}),
#  ('perhaps',
#   'grasping'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'politicians': 294}),
#  ('placate',
#   'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'mutinous': 294}),
#  ('place', 'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 294}),
#  ('platter', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'gold': 294}),
#  ('policy', 'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'have': 294}),
#  ('political',
#   'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'military': 294}),
#  ('political',
#   'freedom'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 294}),
#  ('political',
#   'independence'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'as': 294}),
#  ('political',
#   'parties'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'ever': 294}),
#  ('political',
#   'problems'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 294}),
#  ('politicians',
#   'it'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'is': 294}),
#  ('politics',
#   'no'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'matter': 294}),
#  ('presented',
#   'self'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'government': 294}),
#  ('problems',
#   'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 294}),
#  ('provoked',
#   'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'obstinate': 294}),
#  ('public',
#   'might'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'have': 294}),
#  ('publicly',
#   'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'nigeria': 294}),
#  ('regard', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'killings': 294}),
#  ('reins', 'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 294}),
#  ('republic',
#   'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'solve': 294}),
#  ('restore',
#   'law'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 294}),
#  ('return',
#   'home'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'as': 294}),
#  ('revolution',
#   'into'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'nigerian': 294}),
#  ('right', 'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'assert': 294}),
#  ('s',
#   'government'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'has': 294}),
#  ('scorned', 'at'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'me': 294}),
#  ('self',
#   'government'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'after': 294,
#               'to': 294}),
#  ('services',
#   'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'any': 294}),
#  ('shall', 'make'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'arrangements': 294}),
#  ('shed', 'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 294}),
#  ('six',
#   'constitutional'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'conferences': 294}),
#  ('solve',
#   'political'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'problems': 294}),
#  ('soon', 'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'i': 294}),
#  ('state',
#   'publicly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 294}),
#  ('stop',
#   'further'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'bloodshed': 294}),
#  ('strong', 'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {None: 294}),
#  ('strong',
#   'strong'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'p': 294}),
#  ('struggle',
#   'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'our': 294}),
#  ('style',
#   'margin'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'0': 294}),
#  ('sun', 'this'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'historical': 294}),
#  ('talked', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'colonial': 294}),
#  ('that', 'her'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'majesty': 294}),
#  ('that', 'not'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'a': 294}),
#  ('that', 'our'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'young': 294}),
#  ('the',
#   'british'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'tradition': 294}),
#  ('the',
#   'colonial'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'office': 294}),
#  ('the', 'course'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 294}),
#  ('the',
#   'demerits'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 294}),
#  ('the',
#   'element'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 294}),
#  ('the', 'facts'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 294}),
#  ('the',
#   'federal'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'government': 294}),
#  ('the',
#   'killings'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 294}),
#  ('the',
#   'mutinous'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'officers': 294}),
#  ('the',
#   'nigerian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'armed': 294,
#               'political': 294,
#               'republic': 294}),
#  ('the', 'reins'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'of': 294}),
#  ('the', 'right'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'to': 294}),
#  ('the', 'sun'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'this': 294}),
#  ('they', 'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'our': 294}),
#  ('this',
#   'historical'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'fact': 294}),
#  ('to', 'assert'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'our': 294}),
#  ('to', 'claim'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'that': 294}),
#  ('to', 'gain'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'our': 294}),
#  ('to',
#   'introduce'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 294}),
#  ('to', 'placate'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 294}),
#  ('to', 'restore'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'law': 294}),
#  ('to', 'return'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'home': 294}),
#  ('to', 'solve'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'political': 294}),
#  ('to', 'state'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'publicly': 294}),
#  ('to', 'stop'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'further': 294}),
#  ('to', 'us'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'on': 294, 'the': 294}),
#  ('tradition',
#   'we'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'talked': 294}),
#  ('turks',
#   'decided'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 294}),
#  ('understand',
#   'has'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'now': 294}),
#  ('unfortunate',
#   'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'our': 294}),
#  ('unwise',
#   'policy'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'i': 294}),
#  ('us', 'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'founding': 294}),
#  ('us', 'on'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'a': 294}),
#  ('us', 'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'right': 294}),
#  ('used', 'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'us': 294}),
#  ('violence',
#   'has'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'never': 294}),
#  ('violent',
#   'means'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 294}),
#  ('violent',
#   'revolution'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'into': 294}),
#  ('was', 'shed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'in': 294}),
#  ('we', 'are'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'happy': 294}),
#  ('we', 'talked'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'the': 294}),
#  ('who', 'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'understand': 294}),
#  ('young',
#   'turks'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'decided': 294}),
#  (None, 'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'violence': 294}),
#  (None, None): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#              {'p': 294})}

# %%
#run convert the word occurance scores into probabilities
for words_train in word_model:
    total_count = float(sum(word_model[words_train].values()))
    for word_test in word_model[words_train]:
        word_model[words_train][word_test] /= total_count

# %% [markdown]
# # Predict Words

# %%
#predict the next word after 'the', 'nigerian'
dict(word_model['the', 'nigerian'])
# Out:
# {'armed': 0.3333333333333333,
#  'political': 0.3333333333333333,
#  'republic': 0.3333333333333333}
