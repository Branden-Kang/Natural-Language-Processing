# %% [markdown]
# [Reference](https://pub.towardsai.net/real-time-stock-news-sentiment-analyzer-54eaa91c5634)

# %%
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen, Request

# %%
def get_ticks(url):
    req = Request(url=url,headers={"User-Agent": "Chrome"}) 
    response = urlopen(req)    
    html = BeautifulSoup(response,"html.parser")
    ticks_table = html.find(class_ = 'page')
    
    ticks = list()
    stocks = list()
    for name_box in ticks_table.find_all('a', href = True):
        stocks.append(name_box.text.strip())
        ticks.append(name_box['href'].split('-')[-1].strip())
    d = {'stock':stocks, 'tick':ticks}
    df = pd.DataFrame(data = d)
    return df

# %%
url = "https://www.tickertape.in/stocks"
tick_df = get_ticks(url)
tick_df.head()
# Out:
#                                        stock  tick
# 0                      Adani Enterprises Ltd  ADEL
# 1                     Adani Green Energy Ltd  ADNA
# 2  Adani Ports and Special Economic Zone Ltd  APSE
# 3                            Adani Power Ltd  ADAN
# 4                        Adani Total Gas Ltd  ADAG

# %%
def get_data(url):
    req = Request(url=url,headers={"User-Agent": "Chrome"}) 
    response = urlopen(req).read()    
    html = BeautifulSoup(response,"html.parser")
    news_table = html.find(class_ = 'latest-news-holder')
    
    news = list()
    
    for name_box in news_table.find_all('p', class_='shave-root'):
        news.append(name_box.text.strip())
    
    return news

# %%
news = list()
for i, tick in enumerate(tick_df['tick']):
    url = "https://www.tickertape.in/stocks/" + tick + "/news?checklist=basic&ref=stock-overview_overview-sections&type=news"
    headlines = get_data(url)
    news.append(headlines)

# %%
for i, n in enumerate(news):
    print(i+1, ")", n)
    print('-------')
# Out:
# 1 ) ['Adani Enterprises announces incorporation of step-down subsidiary', 'Adani Enterprises rallies 5%, hits record high; stock soars 27% in a month', 'Stocks that will see action on April 18']
# -------
# 2 ) ['Taking Stock | Market tanks for the fourth day; IT, banks hammered', 'Taking Stock | Market cheers RBI policy, Sensex gains 412 points, Nifty above 17,700', 'M-cap of 7 of top 10 firms tumbles over Rs 1.32 lakh cr; Reliance biggest drag']
# -------
# 3 ) ['Adani Ports buys Ocean Sparkle for Rs 1700 cr through Adani Harbour Svces', 'Adani Ports to acquire marine services firm Ocean Sparkle', 'Taking Stock | Sensex down 575 points, Nifty below 17,700 ahead of RBI policy']
# -------
# 4 ) ['Adani Power rallies 100% in a month to enter 50 most valued cos’ club', 'Adani Power Shares Surge 109% in a Month. Should You Buy, Hold or Sell?', 'Adani Power enters top-50 most-valued firms club; zooms 109% in a month']
# -------
# 5 ) []
# -------
# 6 ) ['Adani Transmission Ltd Spikes 4.45%, S&P BSE Power index Rises 1.75%']
# -------
# 7 ) []
# -------
# 8 ) ['Need a Good Reversal Trade? Ambuja Cements up by 27%!']
# -------
# 9 ) ['Sensex Crashes 704 pts, Nifty Settles Below 16,900; HDFC Twins Tank Up To 6%']
# -------
# 10 ) ['Sensex rises over 874 points to close at 57,912, Nifty ends day at 17,393', 'Sensex jumps 423 points to 57,460 at opening bell, Nifty breaches 17,200', 'Market Roundup: Sensex rises 574 points, Nifty ends at 17,136 points; check top gainers and losers here']
# -------
# 11 ) []
# -------
# 12 ) ['SBI, Bank of Baroda, Axis Bank Hike MCLR Rates: Calculate How it Will Impact Home Loan, Car Loan', 'Axis Bank turns down plan to distribute Sintex sale proceeds', 'Taking Stock | Sensex down 575 points, Nifty below 17,700 ahead of RBI policy']
# -------
# 13 ) ['Focus shifts on incumbents in electric two-wheelers segment', 'Sensex Crashes 704 pts, Nifty Settles Below 16,900; HDFC Twins Tank Up To 6%']
# -------
# 14 ) ['Bajaj Finance Results Preview | Net profit to soar 75% on strong loan growth', 'Hemang Jani on why FIIs are selling HDFC Bank and not Bajaj Finance', 'Market Roundup: Sensex rises 574 points, Nifty ends at 17,136 points; check top gainers and losers here']
# -------
# 15 ) ['Sensex loses over 700 points to end day at 57,197; Nifty below 17,200', 'Sensex drops 715 pts, Nifty holds 17150 in broad-based sell-off; banks sink', 'Sensex rises over 874 points to close at 57,912, Nifty ends day at 17,393']
# -------
# 16 ) ['Bajaj Holdings shares down 0.86% as Sensex rises']
# -------
# 17 ) ['F&O Strategy: Nandish Shah recommends a Bull spread on Bandhan Bank', 'Bandhan Bank stock price up 0.62 per cent as Sensex climbs']
# -------
# 18 ) ['SBI, Bank of Baroda, Axis Bank Hike MCLR Rates: Calculate How it Will Impact Home Loan, Car Loan', 'Bank of Baroda cuts home loan rate by 25 bps to 6.5% till June end', 'Bank of Baroda Home Loan Interest Rates Reduced, But There is a Catch; Details Here']
# -------
# 19 ) ['Berger Paints stock price up 0.45 per cent as Sensex slides']
# -------
# 20 ) []
# -------
# 21 ) ['Centre weighs going back to drawing board on BPCL sale', 'BPCL Disinvestment: Govt Not To Go Ahead With Current Plan; To Draw New Strategy, Says Anil Agarwal', 'BPCL divestment: Govt may take a fresh look, says official']
# -------
# 22 ) ['Airtel vs Jio vs Vi: Best prepaid recharge plans with 3GB daily data and unlimited calls', 'Broker’s call: Bharti Airtel (Buy)', 'WFH or WFO? India Inc decides to wait and watch as cases spike again']
# -------
# 23 ) ['Packaged food likely to see FSSAI health star ratings after one year']
# -------
# 24 ) []
# -------
# 25 ) ['Stock market update: Stocks that hit 52-week lows on NSE in today’s trade', 'Cost pressure likely to weigh on pharma companies’ margins in Q4']
# -------
# 26 ) ['Who were the top gainers and losers last week? Here’s a wrap', 'Trade setup for Friday: Top 15 things to know before Opening Bell', 'Govt moves ahead with proposal to merge Coal India arm with MECL']
# -------
# 27 ) ['DLF to invest Rs 1,700 crore in office space, data centre', 'Preferential location service for a flat will attract 18% GST', 'Large real estate developers enter holiday home mode']
# -------
# 28 ) ['Ayush sector gets investment commitments of Rs 9,000 cr', 'Dabur India to induct 100 EVs in supply chain to reduce carbon emissions', 'Dabur to induct 100 EVs for last mile product distribution']
# -------
# 29 ) []
# -------
# 30 ) ['Taking Stock | Sensex down 575 points, Nifty below 17,700 ahead of RBI policy', 'Sensex drops 715 pts, Nifty holds 17150 in broad-based sell-off; banks sink']
# -------
# 31 ) ['Eicher Motors Ltd Slides 2.39%, S&P BSE Auto index Drops 1.5%', 'Share Market Live: Sensex, Nifty Rise; Eicher Motors, Coal India Surge', 'Taking Stock | Sensex gains 350 points, Nifty above 17,300 on positive global cues']
# -------
# 32 ) ['Weekly rundown: CoinDCX raises $135 mn; Amazon, Nykaa, Gupshup make acquisitions', 'Nykaa announces partnership with three homegrown brands', 'Nykaa makes investments in Earth Rhythm, Onesto Labs, Kica']
# -------
# 33 ) ['GAIL, Hindustan Petroleum to pump in Rs 17,000 cr to boost Bengal CNG infra', 'GAIL, HPCL to pump in Rs 17,000 crore to boost Bengal CNG infra', 'GAIL, HPCL to invest Rs 17,000 cr to boost Bengal CNG infra']
# -------
# 34 ) ['Gland Pharma stock falls over 3% after Nicomac Machinery sells stake', 'Bulk deals | Menu exits Barbeque Nation, Nicomac Machinery cuts stake in Gland Pharma', 'Broker’s call: Gland Pharma (Buy)']
# -------
# 35 ) []
# -------
# 36 ) ['Andhra Pradesh: Jagan to open Grasim Industries unit in East Godavari on April 21', 'Andhra Pradesh: Grasim to commission Chlor-Alkali unit on April 21', 'Sensex Crashes 704 pts, Nifty Settles Below 16,900; HDFC Twins Tank Up To 6%']
# -------
# 37 ) ['Buy HCL Technologies; target of Rs 1310: Motilal Oswal', 'Buy HCL Technologies; target of Rs 1391: KR Choksey', 'HCL sweetens deal for freshers with better pay']
# -------
# 38 ) ['HDFC Bank declares 1550% dividend for shareholders', 'HDFC Bank declares 1550% dividend for shareholders | The Financial Express', 'HDFC Bank declares Rs 15.50 per share dividend for shareholders']
# -------
# 39 ) ['HDFC Life Insurance falls as board to consider fundraising, dividend']
# -------
# 40 ) ['Havells India stock price up 0.44 per cent as Sensex climbs']
# -------
# 41 ) ['Stock market update: Stocks that hit 52-week lows on NSE in today’s trade', 'Sensex falls 500 pts, Nifty below 17,250; Hindalco, SBI, Dr Reddy’s top losers', 'Hindalco Q4 PAT seen up 218% YoY to Rs. 2,075 cr: ICICI Direct']
# -------
# 42 ) []
# -------
# 43 ) ['Taking Stock | Sensex down 575 points, Nifty below 17,700 ahead of RBI policy', 'Sensex, Nifty snap two-day gaining streak amid broad based sell-off', 'Stock market update: Stocks that hit 52-week lows on NSE in today’s trade']
# -------
# 44 ) ['Hindustan Zinc PAT rises 18% to Rs 2,928 crore | The Financial Express', 'Hindustan Zinc Q4 results: Net profit rises 18% to Rs 2,928 cr, revenue jumps 27%', 'Hindustan Zinc consolidated net profit rises 18.02% in the March 2022 quarter']
# -------
# 45 ) ['Who were the top gainers and losers last week? Here’s a wrap', 'HDFC twins are trading at historic valuation discount vs Sensex', 'Taking Stock | Sensex down 575 points, Nifty below 17,700 ahead of RBI policy']
# -------
# 46 ) ['ICICI Bank Q4 net up 59% on fall in provisions | The Financial Express', 'ICICI Bank’s Mulye to join Aditya Birla Capital as CEO', 'Aditya Birla Capital CEO Ajay Srinivasan steps down']
# -------
# 47 ) ['Buy ICICI Lombard General Insurance: target of Rs 1620: Sharekhan', 'Buy ICICI Lombard General Insurance; target of Rs 1612: YES Securities', 'ICICI Lombard General Insurance stock falls as Q4 show disappoints']
# -------
# 48 ) ['Daily Voice | Banking, autos look attractive, but IT needs caution, says Ihab Dalwai of ICICI Prudential AMC', 'Windlas Biotech stock climbs over 4% after ICICI Prudential MF raises stake', 'ICICI Pru MF mergers five fixed maturity plans with its Money Market Fund']
# -------
# 49 ) ['ITC Infotech to buy a portion of Nasdaq-listed PTC’s services business | The Financial Express', 'Inflation a concern but India growth story intact - Sanjiv Puri, CMD at ITC', 'ITC Infotech to acquire part of Boston-based PTC’s product lifecycle management business, float new unit']
# -------
# 50 ) ['Taking Stock | Sensex gains 350 points, Nifty above 17,300 on positive global cues']
# -------
# 51 ) ['Indian Railways Update: IRCTC Cancels 142 Trains on April 23; Check Full List Here', '‘Propagandist’ newspaper distributed on train, IRCTC initiates probe', 'Indian Railways Update: IRCTC Cancels 124 Trains on April 21; Here’s How to Check Full List']
# -------
# 52 ) []
# -------
# 53 ) ['SBI, Bank of Baroda, Axis Bank Hike MCLR Rates: Calculate How it Will Impact Home Loan, Car Loan', 'Sensex, Nifty snap two-day gaining streak amid broad based sell-off', 'Stock market update: Stocks that hit 52-week lows on NSE in today’s trade']
# -------
# 54 ) ['Buy Info Edge (India), target price Rs 5800: ICICI Direct', 'After Sequoia Capital, Info Edge boss Sanjeev Bikhchandani bats for good corporate governance', 'Good governance begins in the founders’ head: Info Edge’s Sanjeev Bikhchandani']
# -------
# 55 ) ['Who were the top gainers and losers last week? Here’s a wrap', 'Weekly market wrap: Sensex slips over 1,100 points; Infosys, HDFC Bank crack', 'Nifty April 2022 futures trades at discount']
# -------
# 56 ) ['Stocks to Watch: HCL Tech, Nestle, Escorts, IndiGo, MRPL, Tata Steel, Nykaa', 'Air traffic grows 37% in March; Indigo share up at 54.8% | The Financial Express', 'Giving wings: Tatas to offer ESOPs to Air India staff to boost productivity']
# -------
# 57 ) ['Stocks that will see action on April 22']
# -------
# 58 ) ['Pawan Hans Disinvestment: JSW Steel, JSPL Bids May Be Decided Soon; Check Details', 'Taking Stock | Sensex gains 350 points, Nifty above 17,300 on positive global cues', 'JSW Steel Q4 PAT seen up 1% YoY to Rs. 4,242 cr: ICICI Direct']
# -------
# 59 ) ['Pawan Hans Disinvestment: JSW Steel, JSPL Bids May Be Decided Soon; Check Details', 'Taking Stock | Market dragged by IT stocks as TCS opens earnings season', 'India has turned into police state: Congress on ED raids on Naveen Jindal']
# -------
# 60 ) ['SBI, Bank of Baroda, Axis Bank Hike MCLR Rates: Calculate How it Will Impact Home Loan, Car Loan', 'Sensex rises over 874 points to close at 57,912, Nifty ends day at 17,393', 'Banks hike MCLR on loans: SBI vs BOB vs Axis Bank vs Kotak Mahindra Bank loan interest rate comparison']
# -------
# 61 ) ['Stocks in news: Tata Elxsi, Reliance Industries, ACC, Coal India and more', 'Larsen & Toubro Infotech Ltd leads losers in ‘A’ group', 'Results Review For L&T Infotech and ACC']
# -------
# 62 ) ['3 stock picks to start building your stock portfolio in this market', 'Mindtree Leases Large Office Space in L&T’s Upcoming Chennai IT Park', 'Axis Securities bullish on these 3 IT stocks post Q4 results']
# -------
# 63 ) ['Macrotech Developers sells office space worth 188 crore to National Realty']
# -------
# 64 ) ['Share Market LIVE: Sensex rises 880 pts, Nifty tops 17,350; M&M, RIL, HDFC top gainers', 'Sensex rises over 874 points to close at 57,912, Nifty ends day at 17,393', 'Market Live: Sensex rises 800 pts, Nifty above 17,350; RIL, TCS, M&M lead']
# -------
# 65 ) []
# -------
# 66 ) ['2022 Nexa XL6 vs New Maruti Suzuki Ertiga detailed spec comparison', 'Who were the top gainers and losers last week? Here’s a wrap', 'Tata Motors announces price hike on cars upto 1.1 per cent']
# -------
# 67 ) ['Mindtree Leases Large Office Space in L&T’s Upcoming Chennai IT Park', 'Mindtree Ltd gains for third consecutive session', 'What potential LTI & Mindtree merger could mean for the respective IT stocks']
# -------
# 68 ) []
# -------
# 69 ) ['WFH or WFO? India Inc decides to wait and watch as cases spike again', 'Alok Industries Ltd leads losers in ‘A’ group']
# -------
# 70 ) ['We disbursed Rs 1 lakh crore gold loan last year: George Alexander Muthoot', 'Muthoot FinCorp launches ‘Mera Gold Loan, Mera Interest’ TV commercial campaign', 'Muthoot FinCorp launches ‘Mera Gold Loan Mera Interest’ TVC campaign']
# -------
# 71 ) ['NMDC Q4 PAT may dip 16% YoY to Rs. 2,391 cr: ICICI Direct']
# -------
# 72 ) ['Taking Stock | Market tanks for the fourth day; IT, banks hammered', 'NTPC ties up with Delhi Jal Board to convert waste into energy', 'Trade setup for Thursday: Top 14 things to know before Opening Bell']
# -------
# 73 ) ['Accumulate Nestle India; target of Rs 19426: Prabhudas Lilladher', 'Inflation hits Nestle India but margins yet to bottom out', 'Covid-19 Cases Rising: Will Companies Again Shift To WFH? Know Plans of TCS, Nestle, Zomato']
# -------
# 74 ) ['Taking Stock | Sensex down 575 points, Nifty below 17,700 ahead of RBI policy', 'Stocks to Watch: RIL, Paytm, ITC, ICICI Bank, HCL Tech, ONGC, NBFCs', 'Got investment proposals worth Rs 3.42 trillion: Mamata Banerjee at Bengal summit | The Financial Express']
# -------
# 75 ) ['Page Industries shares rise 0.45 per cent in Wednesday’s trading session', 'Broker’s call: Page Industries (Buy)']
# -------
# 76 ) ['Share price of Pidilite Ind jumps as Sensex drops 300.97 points', 'Pidilite Ind shares gain 1.75% as Sensex rises']
# -------
# 77 ) []
# -------
# 78 ) []
# -------
# 79 ) ['Deal with Future Retail cannot be implemented: Reliance Industries', 'FRL secured creditors reject Rs 24,713-cr deal with RIL', 'Future - Reliance Deal Scheme “Cannot Be Implemented,” Says RIL']
# -------
# 80 ) ['SBI Cards & Payment Services Ltd spurts 2.33%, up for third straight session', 'SBI Cards & Payment Services Ltd down for fifth straight session']
# -------
# 81 ) ['ICICI Pru, HDFC Life, Bajaj Allianz gain market share in FY22']
# -------
# 82 ) ['Taking Stock | Market cheers RBI policy, Sensex gains 412 points, Nifty above 17,700', 'CCI clears proposal to acquire minority stake in BDR Pharmaceuticals']
# -------
# 83 ) []
# -------
# 84 ) ['Siemens Gamesa Sells Renewables\xa0Portfolio to SSE for $626 Million']
# -------
# 85 ) ['SBI outsourced employee held for cheating customer', 'Fraud Alert! SBI warns customers not to entertain THESE numbers, here’s why', 'SBI, Bank of Baroda, Axis Bank Hike MCLR Rates: Calculate How it Will Impact Home Loan, Car Loan']
# -------
# 86 ) ['Buy Sun Pharmaceutical Industries, target price Rs 975: Kotak Securities', 'Sensex rises over 874 points to close at 57,912, Nifty ends day at 17,393', 'Cost pressure likely to weigh on pharma companies’ margins in Q4']
# -------
# 87 ) ['TCS Recruitment 2022: Graduates can apply for jobs under new hiring program', 'TCS opens co-innovation centre at Carnegie Mellon University', 'Govt seeks to grow tax base, makes filing must for TDS/TCS above Rs 25,000']
# -------
# 88 ) []
# -------
# 89 ) ['Tata Motors hikes prices to curb rising input cost, effective immediately', 'Tata Motors announces price hike on cars upto 1.1 per cent', 'Tata Motors hikes passenger vehicle prices by 1.1 percent, new rates kick in today']
# -------
# 90 ) ['Tata Motors hikes prices to curb rising input cost, effective immediately', 'Tata Motors announces price hike on cars upto 1.1 per cent', 'Tata Motors hikes passenger vehicle prices by 1.1 percent, new rates kick in today']
# -------
# 91 ) ['Tata Power takes Adani to Supreme Court over Rs 7,000-crore transmission contract | The Financial Express', 'Taking Stock | Profit booking pulls Nifty to 17,800; Sensex falls 566 points; power stocks gain', 'Here’s why Mehul Kothari recommends buying Tata Power, Sunteck Realty']
# -------
# 92 ) ['Top picks: Edelweiss recommends these 2 metal stocks to buy', 'Stocks in news: Tata Steel, Tata Elxsi, HCL Tech, ICICI Securities and more', 'Tata Steel stock slips over 2% as firm decides to end business ties with Russia']
# -------
# 93 ) ['Who were the top gainers and losers last week? Here’s a wrap', 'Tech Mahindra to create new revenue streams, 1,000 Jobs in UK', 'tech mahindra: Tech Mahindra to create 1,000 jobs in UK - Times of India']
# -------
# 94 ) ['Taking Stock | Sensex down 575 points, Nifty below 17,700 ahead of RBI policy', 'Titan Company rolls out initiatives to drive more inclusive workforce']
# -------
# 95 ) ['Buy UPL, target price Rs 860: IIFL']
# -------
# 96 ) ['Who are the frontrunners for buying Holcim assets in India?', 'Market Roundup: Sensex rises 574 points, Nifty ends at 17,136 points; check top gainers and losers here', 'Share Market Update: Sensex rises 574 points, Nifty ends above 17,100; Ultratech Cement, Maruti, RIL top gainers']
# -------
# 97 ) []
# -------
# 98 ) ['BPCL Disinvestment: Govt Not To Go Ahead With Current Plan; To Draw New Strategy, Says Anil Agarwal', 'Taking Stock | Market dragged by IT stocks as TCS opens earnings season', 'Vedanta’s Anil Agarwal says corporatising PSUs more rewarding than privatisation']
# -------
# 99 ) ['Wipro to announce Q4 earnings on 29 April', 'Five stocks contributed to 7% fall in Sensex, Nifty in nine sessions', 'Markets open on positive note, Sensex 222 points higher at 56,686; Nifty above 17,000 mark']
# -------
# 100 ) ['Nykaa’s strategic shopping spree; Zomato kicks off 10-min food delivery in Gurgaon', 'Delivery companies try offsetting plastic footprint', 'Zomato to introduce 100% plastic-neutral deliveries']
# -------

# %% [markdown]
# # Sentiment Analysis of Financial News

# %%
pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 22.3 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 8.0 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 49.9 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 52.3 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 53.5 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.5.1 pyyaml-6.0 sacremoses-0.0.49 tokenizers-0.12.1 transformers-4.18.0

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import numpy as np

finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone',num_labels=3)
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')
# Out:
# Downloading:   0%|          | 0.00/533 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/419M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/221k [00:00<?, ?B/s]

# %%
labels = {0:'neutral', 1:'positive',2:'negative'}

# %%
def detect(news):
    tot_val = list()
    for n in news:
        if len(n) == 0:
            tot_val.append(['neutral'])
        else:
            inputs = tokenizer(n, return_tensors="pt", padding=True)
            outputs = finbert(**inputs)[0]
            val = list()
            for idx, sent in enumerate(n):
                val.append(labels[np.argmax(outputs.detach().numpy()[idx])])
                print(sent, '----', val[idx])
            print('#######################################################')    
            tot_val.append(val)
    return tot_val

tot_val = detect(news)
print(tot_val)
# Out:
# Adani Enterprises announces incorporation of step-down subsidiary ---- neutral
# Adani Enterprises rallies 5%, hits record high; stock soars 27% in a month ---- positive
# Stocks that will see action on April 18 ---- neutral
# #######################################################
# Taking Stock | Market tanks for the fourth day; IT, banks hammered ---- negative
# Taking Stock | Market cheers RBI policy, Sensex gains 412 points, Nifty above 17,700 ---- positive
# M-cap of 7 of top 10 firms tumbles over Rs 1.32 lakh cr; Reliance biggest drag ---- negative
# #######################################################
# Adani Ports buys Ocean Sparkle for Rs 1700 cr through Adani Harbour Svces ---- neutral
# Adani Ports to acquire marine services firm Ocean Sparkle ---- neutral
# Taking Stock | Sensex down 575 points, Nifty below 17,700 ahead of RBI policy ---- negative
# #######################################################
# Adani Power rallies 100% in a month to enter 50 most valued cos’ club ---- neutral
# Adani Power Shares Surge 109% in a Month. Should You Buy, Hold or Sell? ---- positive
# Adani Power enters top-50 most-valued firms club; zooms 109% in a month ---- neutral
# #######################################################
# Adani Transmission Ltd Spikes 4.45%, S&P BSE Power index Rises 1.75% ---- neutral
# #######################################################
# Need a Good Reversal Trade? Ambuja Cements up by 27%! ---- positive
# #######################################################
# Sensex Crashes 704 pts, Nifty Settles Below 16,900; HDFC Twins Tank Up To 6% ---- positive
# #######################################################
# Sensex rises over 874 points to close at 57,912, Nifty ends day at 17,393 ---- neutral
# Sensex jumps 423 points to 57,460 at opening bell, Nifty breaches 17,200 ---- positive
# Market Roundup: Sensex rises 574 points, Nifty ends at 17,136 points; check top gainers and losers here ---- positive
# #######################################################
# SBI, Bank of Baroda, Axis Bank Hike MCLR Rates: Calculate How it Will Impact Home Loan, Car Loan ---- neutral
# Axis Bank turns down plan to distribute Sintex sale proceeds ---- neutral
# Taking Stock | Sensex down 575 points, Nifty below 17,700 ahead of RBI policy ---- negative
# #######################################################
# Focus shifts on incumbents in electric two-wheelers segment ---- neutral
# Sensex Crashes 704 pts, Nifty Settles Below 16,900; HDFC Twins Tank Up To 6% ---- positive
# #######################################################
# Bajaj Finance Results Preview | Net profit to soar 75% on strong loan growth ---- positive
# Hemang Jani on why FIIs are selling HDFC Bank and not Bajaj Finance ---- neutral
# Market Roundup: Sensex rises 574 points, Nifty ends at 17,136 points; check top gainers and losers here ---- positive
# #######################################################
# Sensex loses over 700 points to end day at 57,197; Nifty below 17,200 ---- negative
# Sensex drops 715 pts, Nifty holds 17150 in broad-based sell-off; banks sink ---- neutral
# Sensex rises over 874 points to close at 57,912, Nifty ends day at 17,393 ---- neutral
# #######################################################
# Bajaj Holdings shares down 0.86% as Sensex rises ---- negative
# #######################################################
# F&O Strategy: Nandish Shah recommends a Bull spread on Bandhan Bank ---- neutral
# Bandhan Bank stock price up 0.62 per cent as Sensex climbs ---- positive
# #######################################################
# SBI, Bank of Baroda, Axis Bank Hike MCLR Rates: Calculate How it Will Impact Home Loan, Car Loan ---- neutral
# Bank of Baroda cuts home loan rate by 25 bps to 6.5% till June end ---- neutral
# Bank of Baroda Home Loan Interest Rates Reduced, But There is a Catch; Details Here ---- neutral
# #######################################################
# Berger Paints stock price up 0.45 per cent as Sensex slides ---- positive
# #######################################################
# Centre weighs going back to drawing board on BPCL sale ---- neutral
# BPCL Disinvestment: Govt Not To Go Ahead With Current Plan; To Draw New Strategy, Says Anil Agarwal ---- neutral
# BPCL divestment: Govt may take a fresh look, says official ---- neutral
# #######################################################
# Airtel vs Jio vs Vi: Best prepaid recharge plans with 3GB daily data and unlimited calls ---- positive
# Broker’s call: Bharti Airtel (Buy) ---- neutral
# WFH or WFO? India Inc decides to wait and watch as cases spike again ---- neutral
# #######################################################
# Packaged food likely to see FSSAI health star ratings after one year ---- neutral
# #######################################################
# Stock market update: Stocks that hit 52-week lows on NSE in today’s trade ---- neutral
# Cost pressure likely to weigh on pharma companies’ margins in Q4 ---- negative
# #######################################################
# Who were the top gainers and losers last week? Here’s a wrap ---- neutral
# Trade setup for Friday: Top 15 things to know before Opening Bell ---- neutral
# Govt moves ahead with proposal to merge Coal India arm with MECL ---- neutral
# #######################################################
# DLF to invest Rs 1,700 crore in office space, data centre ---- neutral
# Preferential location service for a flat will attract 18% GST ---- neutral
# Large real estate developers enter holiday home mode ---- neutral
# #######################################################
# Ayush sector gets investment commitments of Rs 9,000 cr ---- neutral
# Dabur India to induct 100 EVs in supply chain to reduce carbon emissions ---- neutral
# Dabur to induct 100 EVs for last mile product distribution ---- neutral
# #######################################################
# Taking Stock | Sensex down 575 points, Nifty below 17,700 ahead of RBI policy ---- negative
# Sensex drops 715 pts, Nifty holds 17150 in broad-based sell-off; banks sink ---- neutral
# #######################################################
# Eicher Motors Ltd Slides 2.39%, S&P BSE Auto index Drops 1.5% ---- negative
# Share Market Live: Sensex, Nifty Rise; Eicher Motors, Coal India Surge ---- positive
# Taking Stock | Sensex gains 350 points, Nifty above 17,300 on positive global cues ---- positive
# #######################################################
# Weekly rundown: CoinDCX raises $135 mn; Amazon, Nykaa, Gupshup make acquisitions ---- neutral
# Nykaa announces partnership with three homegrown brands ---- neutral
# Nykaa makes investments in Earth Rhythm, Onesto Labs, Kica ---- neutral
# #######################################################
# GAIL, Hindustan Petroleum to pump in Rs 17,000 cr to boost Bengal CNG infra ---- neutral
# GAIL, HPCL to pump in Rs 17,000 crore to boost Bengal CNG infra ---- neutral
# GAIL, HPCL to invest Rs 17,000 cr to boost Bengal CNG infra ---- neutral
# #######################################################
# Gland Pharma stock falls over 3% after Nicomac Machinery sells stake ---- neutral
# Bulk deals | Menu exits Barbeque Nation, Nicomac Machinery cuts stake in Gland Pharma ---- neutral
# Broker’s call: Gland Pharma (Buy) ---- neutral
# #######################################################
# Andhra Pradesh: Jagan to open Grasim Industries unit in East Godavari on April 21 ---- neutral
# Andhra Pradesh: Grasim to commission Chlor-Alkali unit on April 21 ---- neutral
# Sensex Crashes 704 pts, Nifty Settles Below 16,900; HDFC Twins Tank Up To 6% ---- positive
# #######################################################
# Buy HCL Technologies; target of Rs 1310: Motilal Oswal ---- positive
# Buy HCL Technologies; target of Rs 1391: KR Choksey ---- positive
# HCL sweetens deal for freshers with better pay ---- neutral
# #######################################################
# HDFC Bank declares 1550% dividend for shareholders ---- neutral
# HDFC Bank declares 1550% dividend for shareholders | The Financial Express ---- neutral
# HDFC Bank declares Rs 15.50 per share dividend for shareholders ---- neutral
# #######################################################
# HDFC Life Insurance falls as board to consider fundraising, dividend ---- neutral
# #######################################################
# Havells India stock price up 0.44 per cent as Sensex climbs ---- positive
# #######################################################
# Stock market update: Stocks that hit 52-week lows on NSE in today’s trade ---- neutral
# Sensex falls 500 pts, Nifty below 17,250; Hindalco, SBI, Dr Reddy’s top losers ---- negative
# Hindalco Q4 PAT seen up 218% YoY to Rs. 2,075 cr: ICICI Direct ---- positive
# #######################################################
# Taking Stock | Sensex down 575 points, Nifty below 17,700 ahead of RBI policy ---- negative
# Sensex, Nifty snap two-day gaining streak amid broad based sell-off ---- positive
# Stock market update: Stocks that hit 52-week lows on NSE in today’s trade ---- neutral
# #######################################################
# Hindustan Zinc PAT rises 18% to Rs 2,928 crore | The Financial Express ---- neutral
# Hindustan Zinc Q4 results: Net profit rises 18% to Rs 2,928 cr, revenue jumps 27% ---- positive
# Hindustan Zinc consolidated net profit rises 18.02% in the March 2022 quarter ---- positive
# #######################################################
# Who were the top gainers and losers last week? Here’s a wrap ---- neutral
# HDFC twins are trading at historic valuation discount vs Sensex ---- neutral
# Taking Stock | Sensex down 575 points, Nifty below 17,700 ahead of RBI policy ---- negative
# #######################################################
# ICICI Bank Q4 net up 59% on fall in provisions | The Financial Express ---- positive
# ICICI Bank’s Mulye to join Aditya Birla Capital as CEO ---- neutral
# Aditya Birla Capital CEO Ajay Srinivasan steps down ---- neutral
# #######################################################
# Buy ICICI Lombard General Insurance: target of Rs 1620: Sharekhan ---- neutral
# Buy ICICI Lombard General Insurance; target of Rs 1612: YES Securities ---- positive
# ICICI Lombard General Insurance stock falls as Q4 show disappoints ---- negative
# #######################################################
# Daily Voice | Banking, autos look attractive, but IT needs caution, says Ihab Dalwai of ICICI Prudential AMC ---- positive
# Windlas Biotech stock climbs over 4% after ICICI Prudential MF raises stake ---- positive
# ICICI Pru MF mergers five fixed maturity plans with its Money Market Fund ---- neutral
# #######################################################
# ITC Infotech to buy a portion of Nasdaq-listed PTC’s services business | The Financial Express ---- neutral
# Inflation a concern but India growth story intact - Sanjiv Puri, CMD at ITC ---- negative
# ITC Infotech to acquire part of Boston-based PTC’s product lifecycle management business, float new unit ---- neutral
# #######################################################
# Taking Stock | Sensex gains 350 points, Nifty above 17,300 on positive global cues ---- positive
# #######################################################
# Indian Railways Update: IRCTC Cancels 142 Trains on April 23; Check Full List Here ---- neutral
# ‘Propagandist’ newspaper distributed on train, IRCTC initiates probe ---- neutral
# Indian Railways Update: IRCTC Cancels 124 Trains on April 21; Here’s How to Check Full List ---- neutral
# #######################################################
# SBI, Bank of Baroda, Axis Bank Hike MCLR Rates: Calculate How it Will Impact Home Loan, Car Loan ---- neutral
# Sensex, Nifty snap two-day gaining streak amid broad based sell-off ---- positive
# Stock market update: Stocks that hit 52-week lows on NSE in today’s trade ---- neutral
# #######################################################
# Buy Info Edge (India), target price Rs 5800: ICICI Direct ---- positive
# After Sequoia Capital, Info Edge boss Sanjeev Bikhchandani bats for good corporate governance ---- neutral
# Good governance begins in the founders’ head: Info Edge’s Sanjeev Bikhchandani ---- neutral
# #######################################################
# Who were the top gainers and losers last week? Here’s a wrap ---- neutral
# Weekly market wrap: Sensex slips over 1,100 points; Infosys, HDFC Bank crack ---- neutral
# Nifty April 2022 futures trades at discount ---- neutral
# #######################################################
# Stocks to Watch: HCL Tech, Nestle, Escorts, IndiGo, MRPL, Tata Steel, Nykaa ---- neutral
# Air traffic grows 37% in March; Indigo share up at 54.8% | The Financial Express ---- positive
# Giving wings: Tatas to offer ESOPs to Air India staff to boost productivity ---- positive
# #######################################################
# Stocks that will see action on April 22 ---- neutral
# #######################################################
# Pawan Hans Disinvestment: JSW Steel, JSPL Bids May Be Decided Soon; Check Details ---- neutral
# Taking Stock | Sensex gains 350 points, Nifty above 17,300 on positive global cues ---- positive
# JSW Steel Q4 PAT seen up 1% YoY to Rs. 4,242 cr: ICICI Direct ---- neutral
# #######################################################
# Pawan Hans Disinvestment: JSW Steel, JSPL Bids May Be Decided Soon; Check Details ---- neutral
# Taking Stock | Market dragged by IT stocks as TCS opens earnings season ---- negative
# India has turned into police state: Congress on ED raids on Naveen Jindal ---- neutral
# #######################################################
# SBI, Bank of Baroda, Axis Bank Hike MCLR Rates: Calculate How it Will Impact Home Loan, Car Loan ---- neutral
# Sensex rises over 874 points to close at 57,912, Nifty ends day at 17,393 ---- neutral
# Banks hike MCLR on loans: SBI vs BOB vs Axis Bank vs Kotak Mahindra Bank loan interest rate comparison ---- neutral
# #######################################################
# Stocks in news: Tata Elxsi, Reliance Industries, ACC, Coal India and more ---- neutral
# Larsen & Toubro Infotech Ltd leads losers in ‘A’ group ---- negative
# Results Review For L&T Infotech and ACC ---- neutral
# #######################################################
# 3 stock picks to start building your stock portfolio in this market ---- neutral
# Mindtree Leases Large Office Space in L&T’s Upcoming Chennai IT Park ---- neutral
# Axis Securities bullish on these 3 IT stocks post Q4 results ---- positive
# #######################################################
# Macrotech Developers sells office space worth 188 crore to National Realty ---- neutral
# #######################################################
# Share Market LIVE: Sensex rises 880 pts, Nifty tops 17,350; M&M, RIL, HDFC top gainers ---- positive
# Sensex rises over 874 points to close at 57,912, Nifty ends day at 17,393 ---- neutral
# Market Live: Sensex rises 800 pts, Nifty above 17,350; RIL, TCS, M&M lead ---- positive
# #######################################################
# 2022 Nexa XL6 vs New Maruti Suzuki Ertiga detailed spec comparison ---- neutral
# Who were the top gainers and losers last week? Here’s a wrap ---- neutral
# Tata Motors announces price hike on cars upto 1.1 per cent ---- neutral
# #######################################################
# Mindtree Leases Large Office Space in L&T’s Upcoming Chennai IT Park ---- neutral
# Mindtree Ltd gains for third consecutive session ---- positive
# What potential LTI & Mindtree merger could mean for the respective IT stocks ---- neutral
# #######################################################
# WFH or WFO? India Inc decides to wait and watch as cases spike again ---- neutral
# Alok Industries Ltd leads losers in ‘A’ group ---- negative
# #######################################################
# We disbursed Rs 1 lakh crore gold loan last year: George Alexander Muthoot ---- neutral
# Muthoot FinCorp launches ‘Mera Gold Loan, Mera Interest’ TV commercial campaign ---- neutral
# Muthoot FinCorp launches ‘Mera Gold Loan Mera Interest’ TVC campaign ---- neutral
# #######################################################
# NMDC Q4 PAT may dip 16% YoY to Rs. 2,391 cr: ICICI Direct ---- negative
# #######################################################
# Taking Stock | Market tanks for the fourth day; IT, banks hammered ---- negative
# NTPC ties up with Delhi Jal Board to convert waste into energy ---- neutral
# Trade setup for Thursday: Top 14 things to know before Opening Bell ---- neutral
# #######################################################
# Accumulate Nestle India; target of Rs 19426: Prabhudas Lilladher ---- neutral
# Inflation hits Nestle India but margins yet to bottom out ---- negative
# Covid-19 Cases Rising: Will Companies Again Shift To WFH? Know Plans of TCS, Nestle, Zomato ---- neutral
# #######################################################
# Taking Stock | Sensex down 575 points, Nifty below 17,700 ahead of RBI policy ---- negative
# Stocks to Watch: RIL, Paytm, ITC, ICICI Bank, HCL Tech, ONGC, NBFCs ---- neutral
# Got investment proposals worth Rs 3.42 trillion: Mamata Banerjee at Bengal summit | The Financial Express ---- neutral
# #######################################################
# Page Industries shares rise 0.45 per cent in Wednesday’s trading session ---- neutral
# Broker’s call: Page Industries (Buy) ---- neutral
# #######################################################
# Share price of Pidilite Ind jumps as Sensex drops 300.97 points ---- neutral
# Pidilite Ind shares gain 1.75% as Sensex rises ---- positive
# #######################################################
# Deal with Future Retail cannot be implemented: Reliance Industries ---- neutral
# FRL secured creditors reject Rs 24,713-cr deal with RIL ---- neutral
# Future - Reliance Deal Scheme “Cannot Be Implemented,” Says RIL ---- neutral
# #######################################################
# SBI Cards & Payment Services Ltd spurts 2.33%, up for third straight session ---- positive
# SBI Cards & Payment Services Ltd down for fifth straight session ---- negative
# #######################################################
# ICICI Pru, HDFC Life, Bajaj Allianz gain market share in FY22 ---- positive
# #######################################################
# Taking Stock | Market cheers RBI policy, Sensex gains 412 points, Nifty above 17,700 ---- positive
# CCI clears proposal to acquire minority stake in BDR Pharmaceuticals ---- neutral
# #######################################################
# Siemens Gamesa Sells Renewables Portfolio to SSE for $626 Million ---- neutral
# #######################################################
# SBI outsourced employee held for cheating customer ---- neutral
# Fraud Alert! SBI warns customers not to entertain THESE numbers, here’s why ---- neutral
# SBI, Bank of Baroda, Axis Bank Hike MCLR Rates: Calculate How it Will Impact Home Loan, Car Loan ---- neutral
# #######################################################
# Buy Sun Pharmaceutical Industries, target price Rs 975: Kotak Securities ---- positive
# Sensex rises over 874 points to close at 57,912, Nifty ends day at 17,393 ---- neutral
# Cost pressure likely to weigh on pharma companies’ margins in Q4 ---- negative
# #######################################################
# TCS Recruitment 2022: Graduates can apply for jobs under new hiring program ---- neutral
# TCS opens co-innovation centre at Carnegie Mellon University ---- neutral
# Govt seeks to grow tax base, makes filing must for TDS/TCS above Rs 25,000 ---- positive
# #######################################################
# Tata Motors hikes prices to curb rising input cost, effective immediately ---- positive
# Tata Motors announces price hike on cars upto 1.1 per cent ---- neutral
# Tata Motors hikes passenger vehicle prices by 1.1 percent, new rates kick in today ---- neutral
# #######################################################
# Tata Motors hikes prices to curb rising input cost, effective immediately ---- positive
# Tata Motors announces price hike on cars upto 1.1 per cent ---- neutral
# Tata Motors hikes passenger vehicle prices by 1.1 percent, new rates kick in today ---- neutral
# #######################################################
# Tata Power takes Adani to Supreme Court over Rs 7,000-crore transmission contract | The Financial Express ---- neutral
# Taking Stock | Profit booking pulls Nifty to 17,800; Sensex falls 566 points; power stocks gain ---- positive
# Here’s why Mehul Kothari recommends buying Tata Power, Sunteck Realty ---- neutral
# #######################################################
# Top picks: Edelweiss recommends these 2 metal stocks to buy ---- positive
# Stocks in news: Tata Steel, Tata Elxsi, HCL Tech, ICICI Securities and more ---- neutral
# Tata Steel stock slips over 2% as firm decides to end business ties with Russia ---- negative
# #######################################################
# Who were the top gainers and losers last week? Here’s a wrap ---- neutral
# Tech Mahindra to create new revenue streams, 1,000 Jobs in UK ---- positive
# tech mahindra: Tech Mahindra to create 1,000 jobs in UK - Times of India ---- neutral
# #######################################################
# Taking Stock | Sensex down 575 points, Nifty below 17,700 ahead of RBI policy ---- negative
# Titan Company rolls out initiatives to drive more inclusive workforce ---- neutral
# #######################################################
# Buy UPL, target price Rs 860: IIFL ---- positive
# #######################################################
# Who are the frontrunners for buying Holcim assets in India? ---- neutral
# Market Roundup: Sensex rises 574 points, Nifty ends at 17,136 points; check top gainers and losers here ---- positive
# Share Market Update: Sensex rises 574 points, Nifty ends above 17,100; Ultratech Cement, Maruti, RIL top gainers ---- positive
# #######################################################
# BPCL Disinvestment: Govt Not To Go Ahead With Current Plan; To Draw New Strategy, Says Anil Agarwal ---- neutral
# Taking Stock | Market dragged by IT stocks as TCS opens earnings season ---- negative
# Vedanta’s Anil Agarwal says corporatising PSUs more rewarding than privatisation ---- positive
# #######################################################
# Wipro to announce Q4 earnings on 29 April ---- neutral
# Five stocks contributed to 7% fall in Sensex, Nifty in nine sessions ---- negative
# Markets open on positive note, Sensex 222 points higher at 56,686; Nifty above 17,000 mark ---- positive
# #######################################################
# Nykaa’s strategic shopping spree; Zomato kicks off 10-min food delivery in Gurgaon ---- neutral
# Delivery companies try offsetting plastic footprint ---- neutral
# Zomato to introduce 100% plastic-neutral deliveries ---- neutral
# #######################################################
# [['neutral', 'positive', 'neutral'], ['negative', 'positive', 'negative'], ['neutral', 'neutral', 'negative'], ['neutral', 'positive', 'neutral'], ['neutral'], ['neutral'], ['neutral'], ['positive'], ['positive'], ['neutral', 'positive', 'positive'], ['neutral'], ['neutral', 'neutral', 'negative'], ['neutral', 'positive'], ['positive', 'neutral', 'positive'], ['negative', 'neutral', 'neutral'], ['negative'], ['neutral', 'positive'], ['neutral', 'neutral', 'neutral'], ['positive'], ['neutral'], ['neutral', 'neutral', 'neutral'], ['positive', 'neutral', 'neutral'], ['neutral'], ['neutral'], ['neutral', 'negative'], ['neutral', 'neutral', 'neutral'], ['neutral', 'neutral', 'neutral'], ['neutral', 'neutral', 'neutral'], ['neutral'], ['negative', 'neutral'], ['negative', 'positive', 'positive'], ['neutral', 'neutral', 'neutral'], ['neutral', 'neutral', 'neutral'], ['neutral', 'neutral', 'neutral'], ['neutral'], ['neutral', 'neutral', 'positive'], ['positive', 'positive', 'neutral'], ['neutral', 'neutral', 'neutral'], ['neutral'], ['positive'], ['neutral', 'negative', 'positive'], ['neutral'], ['negative', 'positive', 'neutral'], ['neutral', 'positive', 'positive'], ['neutral', 'neutral', 'negative'], ['positive', 'neutral', 'neutral'], ['neutral', 'positive', 'negative'], ['positive', 'positive', 'neutral'], ['neutral', 'negative', 'neutral'], ['positive'], ['neutral', 'neutral', 'neutral'], ['neutral'], ['neutral', 'positive', 'neutral'], ['positive', 'neutral', 'neutral'], ['neutral', 'neutral', 'neutral'], ['neutral', 'positive', 'positive'], ['neutral'], ['neutral', 'positive', 'neutral'], ['neutral', 'negative', 'neutral'], ['neutral', 'neutral', 'neutral'], ['neutral', 'negative', 'neutral'], ['neutral', 'neutral', 'positive'], ['neutral'], ['positive', 'neutral', 'positive'], ['neutral'], ['neutral', 'neutral', 'neutral'], ['neutral', 'positive', 'neutral'], ['neutral'], ['neutral', 'negative'], ['neutral', 'neutral', 'neutral'], ['negative'], ['negative', 'neutral', 'neutral'], ['neutral', 'negative', 'neutral'], ['negative', 'neutral', 'neutral'], ['neutral', 'neutral'], ['neutral', 'positive'], ['neutral'], ['neutral'], ['neutral', 'neutral', 'neutral'], ['positive', 'negative'], ['positive'], ['positive', 'neutral'], ['neutral'], ['neutral'], ['neutral', 'neutral', 'neutral'], ['positive', 'neutral', 'negative'], ['neutral', 'neutral', 'positive'], ['neutral'], ['positive', 'neutral', 'neutral'], ['positive', 'neutral', 'neutral'], ['neutral', 'positive', 'neutral'], ['positive', 'neutral', 'negative'], ['neutral', 'positive', 'neutral'], ['negative', 'neutral'], ['positive'], ['neutral', 'positive', 'positive'], ['neutral'], ['neutral', 'negative', 'positive'], ['neutral', 'negative', 'positive'], ['neutral', 'neutral', 'neutral']]

# %%
def get_sent(val):
    agg = 0
    for i in val:
        if i == 'positive':
            agg = agg + 1
        elif i == 'negative':
            agg = agg - 1

    if agg > 0:
        return('positive')
    elif agg < 0:
        return('negative')
    else:
        return('neutral')

# %%
sent = list()
for i in tot_val:
    sent.append(get_sent(i))
    
tick_df['sentiment'] = sent 
tick_df.head(20)
# Out:
#                                         stock  tick sentiment
# 0                       Adani Enterprises Ltd  ADEL  positive
# 1                      Adani Green Energy Ltd  ADNA  negative
# 2   Adani Ports and Special Economic Zone Ltd  APSE  negative
# 3                             Adani Power Ltd  ADAN  positive
# 4                         Adani Total Gas Ltd  ADAG   neutral
# 5                      Adani Transmission Ltd  ADAI   neutral
# 6                            Adani Wilmar Ltd   AWL   neutral
# 7                          Ambuja Cements Ltd  ABUJ  positive
# 8             Apollo Hospitals Enterprise Ltd  APLH  positive
# 9                            Asian Paints Ltd  ASPN  positive
# 10                      Avenue Supermarts Ltd  AVEU   neutral
# 11                              Axis Bank Ltd  AXBK  negative
# 12                             Bajaj Auto Ltd  BAJA  positive
# 13                          Bajaj Finance Ltd  BJFN  positive
# 14                          Bajaj Finserv Ltd  BJFS  negative
# 15          Bajaj Holdings and Investment Ltd  BJAT  negative
# 16                           Bandhan Bank Ltd  BANH  positive
# 17                         Bank of Baroda Ltd   BOB   neutral
# 18                    Berger Paints India Ltd  BRGR  positive
# 19                     Bharat Electronics Ltd  BAJE   neutral
