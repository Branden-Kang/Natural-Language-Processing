# %% [markdown]
# [Reference](https://ai.plainenglish.io/run-claude-code-with-local-llms-using-ollama-7f078e433f74)

# %% [markdown]
# # Step 1: Install Claude Code
# ```
# # macOS, Linux, WSL
# curl -fsSL https://claude.ai/install.sh | bash
# # Windows PowerShell
# irm https://claude.ai/install.ps1 | iex
# # Windows CMD
# curl -fsSL https://claude.ai/install.cmd -o install.cmd && install.cmd && del install.cmd
# ```

# %% [markdown]
# # Step 2: Inatall Ollama
# Download and install Ollama from its [website](https://ollama.com/download).

# %% [markdown]
# #  Step 3: Connect Claude Code to Ollama
# ```
# export ANTHROPIC_AUTH_TOKEN=ollama
# export ANTHROPIC_BASE_URL=http://localhost:11434
# ```

# %% [markdown]
# # Step 4: Run Claude Code with a Local/Cloud Models
# ```
# claude --model gpt-oss:20b
# claude --model minimax-m2.1:cloud
# ```
