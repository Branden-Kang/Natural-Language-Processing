# %% [markdown]
# [Reference](https://medium.com/nerd-for-tech/sense2vec-in-python3-9d3db9557495?source=email-221e53167b31-1641491318592-digest.reader-24d8f4fa8912-9d3db9557495----1-59------------------19b412bc_4fbc_4cb2_8e8a_4f518eee9a8b-1-c007094f_6da9_4cee_a1ef_af30d578cea1)

# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# !pip install sense2vec
# !pip install pathlib
# download your pretrained vector set
# !cd directory/with/pretrained/set
# !tar -xvf vectors_md.tar.gz # you should see a s2v_old folder now
# Out:
# ...
#      |████████████████████████████████| 6.0 MB 5.5 MB/s
# ...
#      |████████████████████████████████| 628 kB 51.3 MB/s
# ...
#      |████████████████████████████████| 10.1 MB 40.9 MB/s
# ...
#      |████████████████████████████████| 181 kB 78.6 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 451 kB 59.0 MB/s
# ...
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# ...

# %%
import spacy
from sense2vec import Sense2VecComponent,Sense2Vec                                         
from pathlib import Path

# %%
def get_correlations(KEYWORD):
    nlp = spacy.load("en_core_web_sm") 
    s2v = nlp.add_pipe("sense2vec") 
    path = Path(__file__).parent.joinpath('s2v_old') 
    s2v.from_disk(path) 
    doc = nlp(KEYWORD) 
    assert doc[:].text == KEYWORD 
    freq = doc[:]._.s2v_freq 
    vector = doc[:]._.s2v_vec 
    try: 
       closest_words = list(doc[:]._.s2v_most_similar(30)) 
    except ValueError: 
       print("Nothing found in sense2vec.") 
       return ([])
    correlated = [w[0][0] for w in closest_words if w[1] > 0.70]
    return (list(correlated))
